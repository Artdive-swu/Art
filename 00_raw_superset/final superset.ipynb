# %%
import pandas as pd

# %%
am = "/content/drive/MyDrive/ArtDive/Art/metadata/Amsterdam/amsterdam_dataset_en.csv"
cv = "/content/drive/MyDrive/ArtDive/Art/metadata/Cleveland_Museum/cleveland_dataset.csv"
kg = "/content/drive/MyDrive/ArtDive/Art/metadata/Kaggle/kaggle_dataset.csv"
mp = "/content/drive/MyDrive/ArtDive/Art/metadata/Metropolitan_Museum/metropolitan_dataset.csv"

# %%
am_metadata = pd.read_csv(am, index_col="Unnamed: 0")
print(am_metadata.shape)
cv_metadata = pd.read_csv(cv, index_col="Unnamed: 0")
print(cv_metadata.shape)
kg_metadata = pd.read_csv(kg, index_col="Unnamed: 0")
print(kg_metadata.shape)
mp_metadata = pd.read_csv(mp, index_col="Unnamed: 0")
print(mp_metadata.shape)
# Out:
# (177679, 17)
# (10645, 44)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (103251, 15)
# (34056, 55)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (17,18,25,36,39,40,41,42,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
kg_metadata
# Out:
#                Art_ID                     Title  ...    filename   filesize
# 0       Kaggle_102257                     Uriel  ...  102257.jpg  9201912.0
# 1        Kaggle_75232     Vir Heroicus Sublimis  ...   75232.jpg  8867532.0
# 2        Kaggle_32145                       NaN  ...   32145.jpg  1756681.0
# 3        Kaggle_20304                       NaN  ...   20304.jpg  1942046.0
# 4          Kaggle_836                       NaN  ...     836.jpg  1526212.0
# ...               ...                       ...  ...         ...        ...
# 103246   Kaggle_25525    Number 13A (Arabesque)  ...   25525.jpg    96405.0
# 103247   Kaggle_47038     St. Francis of Assisi  ...   47038.jpg   127594.0
# 103248    Kaggle_7680  Maisons à la campagne II  ...    7680.jpg   102519.0
# 103249    Kaggle_9021           Thebe's Revenge  ...    9021.jpg   167423.0
# 103250   Kaggle_36564             House Manhufe  ...   36564.jpg    77577.0
#
# [103251 rows x 15 columns]

# %%
kg_metadata.columns = ['Art_ID', 'Title', 'Artist', 'Date', 'Worktype', 'Style', 'Material',
       'Subject', 'Measurement', 'Note', 'License', 'Gdrive_ID', 'Period',
       'Filename', 'Filesize']

# %%
am_metadata.head()
# Out:
#                      Art_ID  ... raw_Period
# 0    Amsterdam_RP-T-1985-11  ...         19
# 1  Amsterdam_RP-T-1924-36-6  ...         19
# 2     Amsterdam_RP-T-1912-5  ...         19
# 3    Amsterdam_RP-T-1980-27  ...         17
# 4    Amsterdam_RP-T-1961-88  ...         17
#
# [5 rows x 17 columns]

# %%
am_metadata.columns = ['Art_ID', 'Title', 'Date', 'Material', 'Filename', 'objectNumber',
       'Artist', 'principalOrFirstMaker', 'Measurement', 'description',
       'techniques', 'objectTypes', 'colors', 'dating', 'Gdrive_ID',
       'Filesize', 'raw_Period']

# %%
am_metadata.to_csv(am)

# %%
cv_metadata.head(2)
# Out:
#             Art_ID  ...                        tmp2
# 0  Cleveland_74539  ...                         NaN
# 1  Cleveland_74540  ...  2020-08-26 09:00:05.157000
#
# [2 rows x 44 columns]

# %%
cv_metadata['type'].value_counts()
# Out:
# Print                     8090
# Drawing                   1060
# Painting                  1023
# Bound Volume               253
# Photograph                  94
# Portfolio                   58
# Manuscript                  26
# Portrait Miniature          11
# Tapestry                     8
# Textile                      7
# Glass                        3
# Sculpture                    2
# Furniture and woodwork       1
# Plate                        1
# Mosaic                       1
# Arms and Armor               1
# Monotype                     1
# Miniature                    1
# Jewelry                      1
# Ceramic                      1
# Stone                        1
# Embroidery                   1
# Name: type, dtype: int64

# %%
def findmaterial(row):
  tech = row['Material'] if pd.notnull(row['Material']) else 'NaN'
  sm = row['support_materials'] if pd.notnull(row['support_materials']) else 'NaN'
  coll = row['collection'] if pd.notnull(row['collection']) else 'NaN'
  tp = row['type'] if pd.notnull(row['collection']) else 'NaN'
  return tech + ',' + sm + ',' + coll

# %%
cv_metadata['newmaterial']= cv_metadata.apply(findmaterial,axis=1)

# %%
cv_metadata.columns = ['Art_ID', 'Title', 'Artist', 'id', 'Date', 'techniques', 'Measurement',
       'License', 'Filename', 'Gdrive_ID', 'accession_number',
       'share_license_status', 'tombstone', 'current_location',
       'title_in_original_language', 'series', 'series_in_original_language',
       'creation_date_earliest', 'creation_date_latest', 'culture',
       'support_materials', 'Style', 'collection', 'Work_Type',
       'state_of_the_work', 'edition_of_the_work', 'creditline',
       'inscriptions', 'exhibitions', 'provenance', 'find_spot',
       'related_works', 'fun_fact', 'digital_description', 'wall_description',
       'citations', 'catalogue_raisonne', 'url', 'image_web', 'image_print',
       'image_full', 'updated_at', 'tmp1', 'tmp2', 'newmaerial',
       'Material']

# %%
cv_metadata = cv_metadata[['Art_ID', 'Title', 'Artist', 'Date', 'Work_Type', 'Style',
             'Material', 'Measurement', 'id', 'techniques', 
       'License', 'Filename', 'Gdrive_ID', 'accession_number',
       'share_license_status', 'tombstone', 'current_location',
       'title_in_original_language', 'series', 'series_in_original_language',
       'creation_date_earliest', 'creation_date_latest', 'culture',
       'support_materials', 'collection',
       'state_of_the_work', 'edition_of_the_work', 'creditline',
       'inscriptions', 'exhibitions', 'provenance', 'find_spot',
       'related_works', 'fun_fact', 'digital_description', 'wall_description',
       'citations', 'catalogue_raisonne', 'url', 'image_web', 'image_print',
       'image_full', 'updated_at', 'tmp1', 'tmp2']]

# %%
cv_metadata.columns = ['Art_ID', 'Title', 'Artist', 'Date', 'Worktype', 'Style',
             'Material', 'Measurement', 'id', 'techniques', 
       'License', 'Filename', 'Gdrive_ID', 'accession_number',
       'share_license_status', 'tombstone', 'current_location',
       'title_in_original_language', 'series', 'series_in_original_language',
       'creation_date_earliest', 'creation_date_latest', 'culture',
       'support_materials', 'collection',
       'state_of_the_work', 'edition_of_the_work', 'creditline',
       'inscriptions', 'exhibitions', 'provenance', 'find_spot',
       'related_works', 'fun_fact', 'digital_description', 'wall_description',
       'citations', 'catalogue_raisonne', 'url', 'image_web', 'image_print',
       'image_full', 'updated_at', 'tmp1', 'tmp2']

# %%
mp_metadata.head(2)
# Out:
#               Art_ID  ... License
# 1165  Metmuseum_1668  ...     6.0
# 2379  Metmuseum_3409  ...     6.0
#
# [2 rows x 55 columns]

# %%
def find_mp_material(row):
  medium = row['Material'] if pd.notnull(row['Material']) else 'NaN'
  classi = row['Classification'] if pd.notnull(row['Classification']) else 'NaN'
  return medium + ',' + classi

# %%
mp_metadata['new_material'] = mp_metadata.apply(find_mp_material,axis=1)

# %%
mp_metadata.columns = ['Art_ID', 'Title', 'Artist', 'Date', 'medium', 'Measurement',
       'Object Number', 'Is Highlight', 'Is Timeline Work', 'Is Public Domain',
       'Object ID', 'Department', 'AccessionYear', 'Object Name', 'Culture',
       'raw_Period', 'Dynasty', 'Reign', 'Portfolio', 'Artist Role',
       'Artist Prefix', 'Artist Display Bio', 'Artist Suffix',
       'Artist Alpha Sort', 'Artist Nationality', 'Artist Begin Date',
       'Artist End Date', 'Artist Gender', 'Artist ULAN URL',
       'Artist Wikidata URL', 'Object Begin Date', 'Object End Date',
       'Credit Line', 'Geography Type', 'City', 'State', 'County', 'Country',
       'Region', 'Subregion', 'Locale', 'Locus', 'Excavation', 'River',
       'Classification', 'Rights and Reproduction', 'Link Resource',
       'Object Wikidata URL', 'Metadata Date', 'Repository', 'Tags',
       'Tags AAT URL', 'Filename', 'Gdrive_ID', 'License', 'Material']

# %%
mp_metadata = mp_metadata[
                          ['Art_ID', 'Title', 'Artist', 'Date'
                          , 'Filename', 'Gdrive_ID', 'License', 'Material'
                          , 'Measurement', 'medium',
       'Object Number', 'Is Highlight', 'Is Timeline Work', 'Is Public Domain',
       'Object ID', 'Department', 'AccessionYear', 'Object Name', 'Culture',
       'raw_Period', 'Dynasty', 'Reign', 'Portfolio', 'Artist Role',
       'Artist Prefix', 'Artist Display Bio', 'Artist Suffix',
       'Artist Alpha Sort', 'Artist Nationality', 'Artist Begin Date',
       'Artist End Date', 'Artist Gender', 'Artist ULAN URL',
       'Artist Wikidata URL', 'Object Begin Date', 'Object End Date',
       'Credit Line', 'Geography Type', 'City', 'State', 'County', 'Country',
       'Region', 'Subregion', 'Locale', 'Locus', 'Excavation', 'River',
       'Classification', 'Rights and Reproduction', 'Link Resource',
       'Object Wikidata URL', 'Metadata Date', 'Repository', 'Tags',
       'Tags AAT URL']
]

# %%
superSet = pd.concat([am_metadata, cv_metadata, kg_metadata, mp_metadata])

# %%
superSet.to_csv("/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset.csv")

# %%
superSet.columns[:100]
# Out:
# Index(['Art_ID', 'Title', 'Date', 'Material', 'Filename', 'objectNumber',
#        'Artist', 'principalOrFirstMaker', 'Measurement', 'description',
#        'techniques', 'objectTypes', 'colors', 'dating', 'Gdrive_ID',
#        'Filesize', 'raw_Period', 'Worktype', 'Style', 'id', 'License',
#        'accession_number', 'share_license_status', 'tombstone',
#        'current_location', 'title_in_original_language', 'series',
#        'series_in_original_language', 'creation_date_earliest',
#        'creation_date_latest', 'culture', 'support_materials', 'collection',
#        'state_of_the_work', 'edition_of_the_work', 'creditline',
#        'inscriptions', 'exhibitions', 'provenance', 'find_spot',
#        'related_works', 'fun_fact', 'digital_description', 'wall_description',
#        'citations', 'catalogue_raisonne', 'url', 'image_web', 'image_print',
#        'image_full', 'updated_at', 'tmp1', 'tmp2', 'Subject', 'Note', 'Period',
# ...

# %%
superSet.columns[100:]
# Out:
# Index(['Tags', 'Tags AAT URL'], dtype='object')

# %%
['Art_ID', 'Artist', 'Title', 'Date', 'Period', 'Style', 'Worktype', 
 'Material', 'Measurement',
 'License', 'Filename', 'Filesize', 'Gdrive_ID']
 ['objectNumber', 'principalOrFirstMaker', 'description',
       'techniques', 'objectTypes', 'colors', 'dating',
       'raw_Period', 'id', 'Subject', 'Note',
       'accession_number', 'share_license_status', 'tombstone',
       'current_location', 'title_in_original_language', 'series',
       'series_in_original_language', 'creation_date_earliest',
       'creation_date_latest', 'culture', 'support_materials', 'collection',
       'state_of_the_work', 'edition_of_the_work', 'creditline',
       'inscriptions', 'exhibitions', 'provenance', 'find_spot',
       'related_works', 'fun_fact', 'digital_description', 'wall_description',
       'citations', 'catalogue_raisonne', 'url', 'image_web', 'image_print',
       'image_full', 'updated_at', 'tmp1', 'tmp2', 
       'medium', 'Object Number', 'Is Highlight', 'Is Timeline Work',
       'Is Public Domain', 'Object ID', 'Department', 'AccessionYear',
       'Object Name', 'Culture', 'Dynasty', 'Reign', 'Portfolio',
       'Artist Role', 'Artist Prefix', 'Artist Display Bio', 'Artist Suffix',
       'Artist Alpha Sort', 'Artist Nationality', 'Artist Begin Date',
       'Artist End Date', 'Artist Gender', 'Artist ULAN URL',
       'Artist Wikidata URL', 'Object Begin Date', 'Object End Date',
       'Credit Line', 'Geography Type', 'City', 'State', 'County', 'Country',
       'Region', 'Subregion', 'Locale', 'Locus', 'Excavation', 'River',
       'Classification', 'Rights and Reproduction', 'Link Resource',
       'Object Wikidata URL', 'Metadata Date', 'Repository', 'Tags', 'Tags AAT URL']

# %%
superset_main = superSet[['Art_ID', 'Artist', 'Title', 'Date', 'Period', 'Style', 'Worktype', 
 'Material', 'Measurement',
 'License', 'Filename', 'Filesize', 'Gdrive_ID']]

# %%
superset_main.to_csv("/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv")

# %%
superset_sub = superSet[['objectNumber', 'principalOrFirstMaker', 'description',
       'techniques', 'objectTypes', 'colors', 'dating',
       'raw_Period', 'id', 'Subject', 'Note',
       'accession_number', 'share_license_status', 'tombstone',
       'current_location', 'title_in_original_language', 'series',
       'series_in_original_language', 'creation_date_earliest',
       'creation_date_latest', 'culture', 'support_materials', 'collection',
       'state_of_the_work', 'edition_of_the_work', 'creditline',
       'inscriptions', 'exhibitions', 'provenance', 'find_spot',
       'related_works', 'fun_fact', 'digital_description', 'wall_description',
       'citations', 'catalogue_raisonne', 'url', 'image_web', 'image_print',
       'image_full', 'updated_at', 'tmp1', 'tmp2', 
       'medium', 'Object Number', 'Is Highlight', 'Is Timeline Work',
       'Is Public Domain', 'Object ID', 'Department', 'AccessionYear',
       'Object Name', 'Culture', 'Dynasty', 'Reign', 'Portfolio',
       'Artist Role', 'Artist Prefix', 'Artist Display Bio', 'Artist Suffix',
       'Artist Alpha Sort', 'Artist Nationality', 'Artist Begin Date',
       'Artist End Date', 'Artist Gender', 'Artist ULAN URL',
       'Artist Wikidata URL', 'Object Begin Date', 'Object End Date',
       'Credit Line', 'Geography Type', 'City', 'State', 'County', 'Country',
       'Region', 'Subregion', 'Locale', 'Locus', 'Excavation', 'River',
       'Classification', 'Rights and Reproduction', 'Link Resource',
       'Object Wikidata URL', 'Metadata Date', 'Repository', 'Tags', 'Tags AAT URL']]

# %%
superset_main = pd.read_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv', index_col=[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
superset_main
# Out:
#         Column  ...                          Gdrive_ID
# 0            0  ...  1WD8TD-QteV0hN3Aq8T8aHknX_Pbe_9Ia
# 1            1  ...  1W4wlRRYxknlwbjPImoY-1aw5y7tXlKgQ
# 2            2  ...  1Vyffy-BuO4kZvZ0FPfO8LQr7ruJBckNn
# 3            3  ...  1V3CNuCTu9WTJWgRwynCKbFTKj1V84irJ
# 4            4  ...  1UqrfWbXMyHHYe2YLkTnJRK85vr3q_TX5
# ...        ...  ...                                ...
# 323063  325626  ...  1EibvwS7Y2HEeUrEdhfaVW35dnQxmnBnq
# 323064  325627  ...  1MXpfkjGOX3cZc3BaBHhPJUuQAtRKJmgX
# 323065  325628  ...  1KnSzPG_gFhXYVSCxUmc4bNF7nYwDxQcH
# 323066  325629  ...  1XrycQUZaTAPpYcC3_WKFuQ4CAHB-LYwQ
# 323067  325630  ...  1PLoTzT5AQw4S-tvtyBV0nT7Zfb5oEzly
#
# [323068 rows x 14 columns]

# %%
len(superset_main['Artist'].unique())
# Out:
# 21875

# %%
len(superset_main['Title'].unique())
# Out:
# 232530

# %% [markdown]
# # 데이터 정제

# %%
s =pd.read_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
s=s[s['Title']!='Design for a Stage Set at the Opéra, Paris']

# %%
s['Title'][s['Title']=='unknown title']='Untitled'

# %%
#@title 기본 제목 텍스트
keyword1 = "Landschap met bomen" #@param {type:"string"}
keyword2 = "Landscape with trees" #@param {type:"string"}
s['Title'][s['Title']==keyword1]=keyword2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
s['Title'].value_counts().head(20)
# Out:
# Untitled                                2759
# Brief aan Philip Zilcken                1492
# Self Portrait                            907
# Landscape                                723
# Studie                                   429
# Composition                              367
# Brief aan August Allebé                  279
# Figure studies                           225
# Still Life                               203
# Portrait of a Man                        199
# Annotaties                               191
# Portrait of an unknown man               189
# Illustration to "A Week of Kindness"     175
# Portrait of a Woman                      171
# Aanbidding door de herders               146
# Landscape with trees                     141
# Christus aan het kruis                   135
# Venster met gordijnen                    132
# Brief aan Jan Veth                       132
# Annunciatie                              130
# Name: Title, dtype: int64

# %%
tmp['Title'].value_counts().head(20)
# Out:
# Untitled                                2759
# Self Portrait                            907
# Landscape                                723
# Studie                                   429
# Composition                              367
# Brief aan August Allebé                  279
# Figure studies                           225
# Still Life                               203
# Portrait of a Man                        199
# Annotaties                               191
# Portrait of an unknown man               189
# Illustration to "A Week of Kindness"     175
# Portrait of a Woman                      171
# Aanbidding door de herders               146
# Landscape with trees                     141
# Christus aan het kruis                   135
# Brief aan Jan Veth                       132
# Venster met gordijnen                    132
# Annunciatie                              130
# Winter                                   124
# Name: Title, dtype: int64

# %%
s.to_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv')

# %% [markdown]
# ### breif 제거 작업

# %%
len(tmp.loc[tmp['Title'].notnull()&tmp['Title'].str.contains('Brief'),'Title'])
# Out:
# 437

# %%
tmp2 = tmp.loc[tmp['Title'].notnull()&tmp['Title'].str.contains('Brief')]

# %%
tmp2[['Art_ID','Material','Gdrive_ID']].to_csv('/content/drive/MyDrive/ArtDive/Data Cleansing/Brief_check.csv')

# %%
breif = 'Amsterdam_RP-P-1992-401,Amsterdam_RP-D-2012-5-2,Amsterdam_RP-D-1996-1-48A,Amsterdam_RP-D-1982-43-A.PIT-33,Amsterdam_RP-D-1982-43-A.PIT-116,Amsterdam_RP-D-1982-43-A.PIT-105,Amsterdam_RP-D-1982-43-A.PIT-69,Amsterdam_RP-D-1982-43-LEOPOLD(H.P.)-6,Amsterdam_RP-D-1982-43-LENAIN(L.)-2,Amsterdam_RP-D-1982-43-MARX(ROGER)-11,Amsterdam_RP-D-1982-43-LEOPOLD(H.P.)-3,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-6,Amsterdam_RP-D-1982-43-MARIS(JACOB)-6,Amsterdam_RP-D-1982-43-MAETERLINCK(R.)-14,Amsterdam_RP-D-1982-43-MARIS(JACOB)-2,Amsterdam_RP-D-1982-43-MAETERLINCK(R.)-17,Amsterdam_RP-D-1982-43-LAURENS(J-P.)-1,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-1,Amsterdam_RP-D-1982-43-LEOPOLD(H.P.)-2,Amsterdam_RP-D-1982-43-MAETERLINCK(R.)-20,Amsterdam_RP-D-1982-43-MARIS(JACOB)-7,Amsterdam_RP-D-1982-43-MARIS(ANNIE)-2,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-14,Amsterdam_RP-D-1982-43-MARIS(MATTHIJS)-3,Amsterdam_RP-D-1982-43-MARISJBZN(W.)-1,Amsterdam_RP-D-1982-43-MARX(ROGER)-24,Amsterdam_RP-D-1982-43-LEEMANS(C.)-2,Amsterdam_RP-D-1982-43-MARIS(MATTHIJS)-1,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-7,Amsterdam_RP-D-1982-43-LEOPOLD(H.P.)-1,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-10,Amsterdam_RP-D-1982-43-MAETERLINCK(R.)-16,Amsterdam_RP-D-1982-43-MAETERLINCK(R.)-12,Amsterdam_RP-D-1982-43-LEOPOLD(H.P.)-7,Amsterdam_RP-D-1982-43-MARX(ROGER)-18,Amsterdam_RP-D-1982-43-MARX(ROGER)-4,Amsterdam_RP-D-1982-43-DELALAURENCIE(L.)-1,Amsterdam_RP-D-1982-43-MESDAG.V.HOUTEN-1,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-22,Amsterdam_RP-D-1982-43-LEMONNIER(C.)-10A,Amsterdam_RP-D-1982-43-MANSFIELD(H.)-2,Amsterdam_RP-D-1982-43-MAETERLINCK(M.)-13,Amsterdam_RP-D-1982-43-MARX(ROGER)-6,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-20B,Amsterdam_RP-D-1982-43-LENAIN(L.)-1,Amsterdam_RP-D-1982-43-LEOPOLD(H.P.)-5A,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-3,Amsterdam_RP-D-1982-43-MARX(ROGER)-25,Amsterdam_RP-D-1982-43-MAETERLINCK(R.)-19,Amsterdam_RP-D-1982-43-MARIS(MATTHIJS)-2,Amsterdam_RP-D-1982-43-MARIS(JACOB)-5,Amsterdam_RP-D-1982-43-MAETERLINCK(R.)-15,Amsterdam_RP-D-1982-43-MARX(ROGER)-21,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-37,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-36,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-9,Amsterdam_RP-D-1982-43-LEOPOLD(H.P.)-4A,Amsterdam_RP-D-1982-43-LEMONNIER(C.)-7,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-26,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-12,Amsterdam_RP-D-1982-43-MARX(ROGER)-23,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-15,Amsterdam_RP-D-1982-43-LENSEIGNE(G.)-1,Amsterdam_RP-D-1982-43-MARIS(JACOB)-1,Amsterdam_RP-D-1982-43-MANSFIELD(H.)-1,Amsterdam_RP-D-1982-43-DEMEYIER(F.)-43,Amsterdam_RP-D-1982-43-MARIS(ANNIE)-1,Amsterdam_RP-D-2017-2401,Amsterdam_RP-D-2017-2397,Amsterdam_RP-D-2017-2450,Amsterdam_BI-1950-17-112,Amsterdam_RP-D-2017-2390,Amsterdam_RP-D-2017-2358,Amsterdam_BI-1950-17-113,Amsterdam_RP-D-2017-2398,Amsterdam_RP-D-2017-2407,Amsterdam_RP-D-2017-2368,Amsterdam_RP-D-2017-2364,Amsterdam_RP-D-2017-2393,Amsterdam_BI-1950-17-118,Amsterdam_RP-D-2017-2372,Amsterdam_RP-D-2017-2452-53,Amsterdam_RP-D-1982-43-NAKKEN(WC.)-1,Amsterdam_RP-D-1982-43-OFFERMANS(T.)-9,Amsterdam_RP-D-1982-43-MOUREY(G.)-5,Amsterdam_BI-1950-17-652,Amsterdam_RP-D-1982-43-MOUREY(G.)-8,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-9,Amsterdam_RP-D-1982-43-MOUREY(G.)-7,Amsterdam_BI-1950-17-651,Amsterdam_RP-D-1982-43-MESKER(T.L.)-1,Amsterdam_RP-D-1982-43-MOUREY(G.)-4,Amsterdam_BI-1950-17-642,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-6,Amsterdam_RP-D-1982-43-MULLER(W.)-2A,Amsterdam_RP-D-1982-43-MALLARME(S.)-6,Amsterdam_RP-D-1982-43-NAKKEN(WC.)-3,Amsterdam_RP-D-1982-43-NEWBERRY(F.)-1,Amsterdam_RP-D-1982-43-PASCHAL(L.)-5B,Amsterdam_RP-D-1982-43-MULLER(W.)-1B,Amsterdam_RP-D-1982-43-NEUHUYS(A.)-3,Amsterdam_RP-D-1982-43-LOUDON(J.)-7,Amsterdam_RP-D-1982-43-MALLARME(S.)-8BA,Amsterdam_RP-D-1982-43-NEUHUYS(A.)-2,Amsterdam_RP-D-1982-43-MULDER(L.)-1,Amsterdam_RP-D-1982-43-OFFERMANS(T.)-7,Amsterdam_RP-D-1982-43-MULLER(PROF.P.J.)-1,Amsterdam_RP-D-1982-43-OPPENOORT(W.J.)-2,Amsterdam_RP-D-1982-43-NAKKEN(WC.)-DOC.2,Amsterdam_RP-D-1982-43-PASCHAL(L.)-3,Amsterdam_RP-D-1982-43-MEYNIER(L.)-1,Amsterdam_RP-D-1982-43-OFFERMANS(T.)-10,Amsterdam_RP-D-1982-43-MOUREY(G.)-6,Amsterdam_RP-D-1982-43-MOUREY(G.)-2,Amsterdam_RP-D-1982-43-OFFERMANS(T.)-8,Amsterdam_RP-D-1982-43-GUBRICY(V.)-1A,Amsterdam_RP-D-1982-43-ERLICH(J.)-19,Amsterdam_RP-D-1982-43-EPHRUSSI(CH.)-2,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-16,Amsterdam_RP-D-1982-43-EISLER(DR.MAX)-1,Amsterdam_RP-D-1982-43-HADKINSON(E.)-12,Amsterdam_RP-D-1982-43-HADKINSON(E.)-22B,Amsterdam_RP-D-1982-43-GUBRICY(V.)-2,Amsterdam_RP-D-1984-40-J.P.VETH-1,Amsterdam_RP-D-2017-1972,Amsterdam_RP-D-2017-1965,Amsterdam_RP-D-2017-1932,Amsterdam_RP-D-1982-43-L.BERGER-5,Amsterdam_RP-D-1982-43-COTTET-1,Amsterdam_RP-D-1982-43-L.BISTOLFI-1,Amsterdam_RP-D-1982-43-L.BERGER-13,Amsterdam_RP-D-1982-43-GEUNS(C.VAN)-2,Amsterdam_RP-D-1982-43-GILBERTDEVOISINS-6A,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-101,Amsterdam_RP-D-1982-43-J.COMTE-12,Amsterdam_RP-D-1982-43-GIESE(J.)-6,Amsterdam_RP-T-2000-110-98(V),Amsterdam_RP-T-2000-110-97(R),Amsterdam_RP-D-1982-43-M.BERNARD-1,Amsterdam_RP-D-1982-43-A.PIT-53,Amsterdam_RP-D-1982-43-L.BERGER-10,Amsterdam_RP-D-1982-43-A.PIT-60,Amsterdam_RP-D-1982-43-A.PIT-48,Amsterdam_RP-D-1982-43-A.PIT-104,Amsterdam_RP-D-1982-43-A.PIT-31,Amsterdam_RP-D-1982-43-A.PIT-56,Amsterdam_RP-D-1982-43-A.PIT-30,Amsterdam_RP-D-1982-43-A.PIT-34,Amsterdam_RP-D-1982-43-A.PIT-121,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-22,Amsterdam_RP-D-1982-43-A.PIT-32,Amsterdam_RP-D-1982-43-A.PIT-47,Amsterdam_RP-D-1982-43-A.PIT-118,Amsterdam_RP-D-1982-43-A.PIT-29,Amsterdam_RP-D-1982-43-A.PIT-90,Amsterdam_RP-D-1982-43-A.PIT-149,Amsterdam_RP-D-1982-43-A.PIT-59,Amsterdam_RP-D-1982-43-A.PIT-45,Amsterdam_RP-D-1982-43-A.PIT-68,Amsterdam_RP-D-1982-43-A.PIT-27,Amsterdam_RP-D-1982-43-A.PIT-49,Amsterdam_RP-D-1982-43-A.PIT-26,Amsterdam_RP-D-1982-43-A.PIT-50,Amsterdam_RP-D-1982-43-A.PIT-54,Amsterdam_RP-D-1982-43-A.PIT-98,Amsterdam_RP-D-1982-43-A.PIT-119,Amsterdam_RP-D-1982-43-A.PIT-57,Amsterdam_RP-D-1982-43-A.PIT-96,Amsterdam_RP-D-1982-43-COOPMAN-1,Amsterdam_RP-D-1982-43-A.PIT-123,Amsterdam_RP-D-1982-43-A.PIT-36,Amsterdam_RP-D-1982-43-CRAMER-1,Amsterdam_RP-D-1982-43-A.PIT-25,Amsterdam_RP-D-1982-43-CRABBE-1,Amsterdam_RP-D-1982-43-A.PIT-146,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-24,Amsterdam_RP-D-1982-43-A.PIT-102,Amsterdam_RP-D-1982-43-A.PIT-55,Amsterdam_RP-D-1982-43-A.PIT-92,Amsterdam_RP-D-1982-43-A.PIT-114,Amsterdam_RP-D-1982-43-A.PIT-23,Amsterdam_RP-D-1982-43-A.PIT-115,Amsterdam_RP-D-1982-43-A.PIT-153,Amsterdam_RP-D-1982-43-A.PIT-108,Amsterdam_RP-D-1982-43-A.PIT-35,Amsterdam_RP-D-1982-43-A.PIT-52,Amsterdam_RP-D-1982-43-A.PIT-107,Amsterdam_RP-D-1982-43-A.PIT-51,Amsterdam_RP-D-1982-43-A.PIT-38,Amsterdam_RP-D-1982-43-A.PIT-109,Amsterdam_RP-D-1982-43-A.PIT-46,Amsterdam_RP-D-1982-43-A.PIT-67,Amsterdam_RP-D-1982-43-A.PIT-24,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-10,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-12,Amsterdam_RP-D-1982-43-A.PIT-91,Amsterdam_RP-D-1982-43-A.PIT-28,Amsterdam_RP-D-1982-43-CHATINE-1,Amsterdam_RP-D-1982-43-CHARPENTIER-1,Amsterdam_RP-D-1982-43-CASSATT-3,Amsterdam_RP-D-1982-43-L.BOURGEOIS-2,Amsterdam_RP-D-1982-43-G.BOURCARD-3,Amsterdam_RP-D-1982-43-CLAPIER-H.-2,Amsterdam_RP-D-1982-43-CASSATT-5,Amsterdam_RP-D-1982-43-CHARRIANT-2,Amsterdam_RP-D-1982-43-G.BOURCARD-6,Amsterdam_RP-D-1982-43-BOELS(J)-21,Amsterdam_RP-D-1982-43-BOELS(J)-16,Amsterdam_RP-D-1982-43-CHARPENTIER-2,Amsterdam_RP-D-1982-43-CLAUS-3,Amsterdam_RP-D-1982-43-G.BOURCARD-4,Amsterdam_RP-D-1982-43-CASSATT-7,Amsterdam_RP-D-1982-43-CASSATT-4,Amsterdam_RP-D-1982-43-G.BOURCARD-13,Amsterdam_RP-D-1982-43-CAZALS-3,Amsterdam_RP-D-1982-43-BOELS(J)-24,Amsterdam_RP-D-1982-43-BOELS(J)-12,Amsterdam_RP-D-1982-43-A.BOUTEVEILLE-1,Amsterdam_RP-D-1982-43-CARO-DELVAILLE-1,Amsterdam_RP-D-1982-43-G.BOURCARD-9,Amsterdam_RP-D-1982-43-BOELS(J)-20,Amsterdam_RP-D-1982-43-BOELS(J)-15,Amsterdam_RP-D-1982-43-CHARPENTIER-3,Amsterdam_RP-D-1982-43-BOELS(J)-9,Amsterdam_RP-D-1982-43-G.BOURCARD-17,Amsterdam_RP-D-1982-43-CAZALS-2,Amsterdam_RP-D-1982-43-E.BOUCABEILLE-1,Amsterdam_RP-D-1982-43-G.BOURCARD-10,Amsterdam_RP-D-1982-43-G.BOURCARD-5,Amsterdam_RP-D-1982-43-BOELS(J)-17,Amsterdam_RP-D-1982-43-L.BOURGEOIS-1,Amsterdam_RP-D-1982-43-G.BOURCARD-1,Amsterdam_RP-D-1982-43-CLAUS-4,Amsterdam_RP-D-1982-43-CATTIER-2,Amsterdam_RP-D-1982-43-BOELS(J)-27,Amsterdam_RP-D-1982-43-CASSATT-8,Amsterdam_RP-D-1982-43-BOELS(J)-13,Amsterdam_RP-D-1982-43-CLAPIER-H.-1,Amsterdam_RP-D-1982-43-BOELS(J)-19,Amsterdam_RP-D-1982-43-G.BOURCARD-8,Amsterdam_RP-D-1982-43-CHARRIANT-4,Amsterdam_RP-D-1982-43-CASSATT-6,Amsterdam_RP-D-1982-43-CASSATT-2,Amsterdam_RP-D-1982-43-CLAUS-2,Amsterdam_RP-D-1982-43-G.BOURCARD-7,Amsterdam_RP-D-1982-43-CATTIER-1,Amsterdam_RP-D-1982-43-CLAUS-1,Amsterdam_RP-D-1982-43-CHARPENTIER-4,Amsterdam_RP-D-1982-43-CHATINE-3,Amsterdam_RP-D-1982-43-CHESNEAU-1,Amsterdam_RP-D-1982-43-CAZALS-1,Amsterdam_RP-D-1982-43-CHATINE-2,Amsterdam_RP-D-1982-43-G.BOURCARD-11,Amsterdam_RP-D-1982-43-J.BOLDINI-1,Amsterdam_RP-D-1982-43-G.BOURCARD-2,Amsterdam_RP-D-1982-43-G.BOURCARD-12,Amsterdam_RP-D-1982-43-CRANE-1,Amsterdam_RP-D-1982-43-L.BERGER-3,Amsterdam_RP-D-1982-43-B.J.BLOMMERS-5,Amsterdam_RP-D-1982-43-COUPERUS-2,Amsterdam_RP-D-1982-43-COURBOIN-2,Amsterdam_RP-D-1982-43-CRANE-3,Amsterdam_RP-D-1982-43-L.BERGER-8,Amsterdam_RP-D-1982-43-CRANE-5,Amsterdam_RP-D-1982-43-L.BERGER-4,Amsterdam_RP-D-1982-43-L.BERGER-7,Amsterdam_RP-D-1982-43-CRANE-4,Amsterdam_RP-D-1982-43-L.BERGER-6,Amsterdam_RP-D-1982-43-L.BERGER-11,Amsterdam_RP-D-1982-43-L.BERGER-12,Amsterdam_RP-D-1982-43-CRANE-6,Amsterdam_RP-D-1982-43-CONSTANT-1,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-26,Amsterdam_RP-D-1982-43-A.PIT-39,Amsterdam_RP-D-1981-12,Amsterdam_RP-D-2017-1343,Amsterdam_RP-D-2017-1180,Amsterdam_RP-D-2017-1186,Amsterdam_RP-D-2017-1200,Amsterdam_RP-D-2017-1293,Amsterdam_RP-D-2017-1291,Amsterdam_RP-D-2017-1170,Amsterdam_RP-D-2017-1145,Amsterdam_RP-D-2017-1255,Amsterdam_RP-D-2017-1142,Amsterdam_RP-D-2017-1283,Amsterdam_RP-D-2017-1312,Amsterdam_RP-D-2017-1202,Amsterdam_RP-D-1981-19,Amsterdam_RP-D-1907-89-1,Amsterdam_RP-D-2017-1206,Amsterdam_RP-D-2017-1240,Amsterdam_RP-D-2017-1254,Amsterdam_RP-D-2017-1120,Amsterdam_RP-D-2017-1233,Amsterdam_RP-D-2017-1125,Amsterdam_RP-D-2017-1294,Amsterdam_RP-D-2017-1276,Amsterdam_RP-D-2017-1324,Amsterdam_RP-D-2017-1227,Amsterdam_RP-D-2017-1178,Amsterdam_RP-D-2017-1313,Amsterdam_RP-D-2017-1235,Amsterdam_RP-D-2017-1130,Amsterdam_RP-D-2017-1245,Amsterdam_RP-D-2017-1314,Amsterdam_RP-D-2017-1183,Amsterdam_RP-D-2017-1173,Amsterdam_RP-D-2017-1292,Amsterdam_RP-D-2017-1182,Amsterdam_RP-D-2017-1124,Amsterdam_RP-D-2017-1250,Amsterdam_RP-D-2017-1112,Amsterdam_RP-D-2017-1325,Amsterdam_RP-D-2017-1189,Amsterdam_RP-D-2017-1246,Amsterdam_RP-D-2017-1244,Amsterdam_RP-D-2017-1211,Amsterdam_RP-D-2017-1257,Amsterdam_RP-D-2017-1260,Amsterdam_RP-D-2017-1174,Amsterdam_RP-D-2017-1148,Amsterdam_RP-D-2017-1237,Amsterdam_RP-D-2017-1141,Amsterdam_RP-D-2017-1171,Amsterdam_RP-D-2017-1281,Amsterdam_RP-D-2017-1150,Amsterdam_RP-D-2017-1284,Amsterdam_RP-D-2017-1326,Amsterdam_RP-D-2017-1242,Amsterdam_RP-D-2017-1328,Amsterdam_RP-D-2017-1117,Amsterdam_RP-D-2017-1269,Amsterdam_RP-D-2017-1234,Amsterdam_RP-D-2017-1201,Amsterdam_RP-D-2017-1187,Amsterdam_RP-D-2017-1263,Amsterdam_RP-D-2017-1268,Amsterdam_RP-D-2017-1121,Amsterdam_RP-D-1982-43-A.ALEXANDRE-6,Amsterdam_RP-D-1982-43-A.ALEXANDRE-8,Amsterdam_RP-D-1982-43-ALBAN-1,Amsterdam_RP-D-1982-43-H.ASSELIN-3,Amsterdam_RP-D-1982-43-CREMERS(R)-1,Amsterdam_RP-D-1982-43-M.BIERME-6,Amsterdam_RP-D-1982-43-A.ALEXANDRE-10,Amsterdam_RP-D-1982-43-CREMERS(R)-4,Amsterdam_RP-D-1982-43-L.BERGER-28,Amsterdam_RP-D-1982-43-CREMERS(E)-1,Amsterdam_RP-D-1982-43-L.BIZIO-3,Amsterdam_RP-D-1982-43-L.BERTRAND-2,Amsterdam_RP-D-1982-43-AVERY-4,Amsterdam_RP-D-1982-43-L.BERGER-21,Amsterdam_RP-D-1982-43-M.BIERME-1,Amsterdam_RP-D-1982-43-A.ANTOINE-1,Amsterdam_RP-D-1982-43-AVERY-1,Amsterdam_RP-D-1982-43-L.BERGER-29,Amsterdam_RP-D-1982-43-H.ASSELIN-1,Amsterdam_RP-D-1982-43-F.AUBERT-1,Amsterdam_RP-D-1982-43-A.ALEXANDRE-9,Amsterdam_RP-D-1982-43-A.ALEXANDRE-4,Amsterdam_RP-D-1982-43-CREMERS(R)-5,Amsterdam_RP-D-1982-43-L.BERGER-25,Amsterdam_RP-D-1982-43-A.D.D-ALEZZIO-1,Amsterdam_RP-D-1982-43-L.BERGER-17,Amsterdam_RP-D-1982-43-M.BIERME-5,Amsterdam_RP-D-1982-43-CREMERS(R)-2,Amsterdam_RP-D-1982-43-M.DESBOUTINS-4,Amsterdam_RP-D-1982-43-L.BENEDITE-25,Amsterdam_RP-D-1982-43-GRAM(J.)-7,Amsterdam_RP-D-1982-43-M.BENOIDT-1,Amsterdam_RP-D-1982-43-L.BENEDITE-14,Amsterdam_RP-D-1982-43-DESLANDES-4B,Amsterdam_RP-D-1982-43-GRANDCARTERET(J.)-1,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-65,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-47,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-60,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-66,Amsterdam_NG-NM-4282-3(R),Amsterdam_NG-NM-4282-3(V),Amsterdam_RP-D-2017-1415,Amsterdam_RP-D-MOUILLERON.A-47,Amsterdam_RP-D-2017-1567,Amsterdam_RP-D-1982-43-DESLANDES-23,Amsterdam_RP-D-2017-1296,Amsterdam_RP-D-2017-1407,Amsterdam_RP-D-2017-1591,Amsterdam_RP-D-2017-1427,Amsterdam_RP-D-2017-1560,Amsterdam_RP-D-1982-43-L.BENEDITE-2,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-8,Amsterdam_RP-D-1982-43-HERBIET-1,Amsterdam_RP-D-1982-43-HOLBACH(A.)-4,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-4,Amsterdam_RP-D-1982-43-KRABBE(H.M.)-1,Amsterdam_RP-D-1982-43-JANSEN(H.W.)-1,Amsterdam_RP-D-1982-43-HOLBACH(A.)-8,Amsterdam_RP-D-1982-43-A.DELZANT-5,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-3,Amsterdam_RP-D-1982-43-A.DELZANT-24,Amsterdam_RP-D-1982-43-A.DELZANT-10,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-8,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-2,Amsterdam_RP-D-1982-43-HOLBACH(A.)-6,Amsterdam_RP-D-1982-43-VANHOUTEN(B.E.)-24,Amsterdam_RP-D-1982-43-DEKOO(J.)-13,Amsterdam_RP-D-1982-43-DEMEESTER(J.)-1B,Amsterdam_RP-D-1982-43-DEKOO(J.)-19,Amsterdam_RP-D-1982-43-MASSON(CH.)-11,Amsterdam_RP-D-1982-43-DEKOO(J.)-29,Amsterdam_RP-D-1982-43-HEIJERMANS(H.)-1,Amsterdam_RP-D-1982-43-HAVERMAN(H.J.)-28,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-5,Amsterdam_RP-D-1982-43-HOLBACH(A.)-1,Amsterdam_RP-D-1982-43-HERSCHEL(MEJ.A.)-1,Amsterdam_BI-1950-17-55,Amsterdam_BI-1950-17-48,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-11,Amsterdam_RP-D-1982-43-HOLBACH(A.)-10,Amsterdam_RP-D-1982-43-HAVERMAN(H.J.)-26,Amsterdam_BI-1950-17-53,Amsterdam_RP-D-R.N.ROLANDHOLST-109,Amsterdam_BI-1950-17-81,Amsterdam_RP-D-1982-43-HENKES(G.)-1,Amsterdam_BI-1950-17-6,Amsterdam_RP-T-1998-60-6(R),Amsterdam_RP-D-1982-43-J.AUROUZE-1,Amsterdam_RP-D-1982-43-L.BERGER-23,Amsterdam_RP-D-1982-43-L.BERGER-30,Amsterdam_RP-D-1982-43-L.BERGER-27,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-63,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-49,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-70,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-67,Amsterdam_RP-D-1982-43-L.BERGER-16,Amsterdam_RP-D-1982-43-L.BERLINN-2,Amsterdam_RP-D-1982-43-L.BERGER-14,Amsterdam_RP-D-1982-43-L.BERGER-18,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-68,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-45,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-69,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-50,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-55,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-54,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-46,Amsterdam_RP-D-1982-43-M.DESBOUTINS-2,Amsterdam_RP-D-1982-43-DESLANDES-4A,Amsterdam_RP-D-1982-43-GRANGE(ANT.)-1,Amsterdam_RP-D-1982-43-DESLANDES-8,Amsterdam_RP-D-1982-43-DIEPENBROCK-20,Amsterdam_RP-D-1982-43-DESLANDES-22A,Amsterdam_RP-D-2016-6-123,Amsterdam_RP-D-2016-6-129,Amsterdam_RP-D-1982-43-GROSHANS(SUZE)-6,Amsterdam_RP-D-1982-43-ERLICH(J.)-9,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-1,Amsterdam_RP-D-2017-1855,Amsterdam_RP-D-1982-43-HADKINSON(E.)-3C,Amsterdam_RP-D-1982-43-HADKINSON(E.)-16,Amsterdam_RP-D-1982-43-BASCH.IMRE-1,Amsterdam_RP-D-2017-1741,Amsterdam_RP-D-1982-43-GUBRICY(V.)-1B,Amsterdam_RP-D-1982-43-EEKHOUD(G.)-5,Amsterdam_RP-D-2017-1720,Amsterdam_RP-D-2017-1850,Amsterdam_RP-D-1982-43-HADKINSON(E.)-10A,Amsterdam_RP-D-1982-43-ERLICH(J.)-8B,Amsterdam_RP-D-2017-1920,Amsterdam_RP-D-1982-43-EEDEN(F.VAN)-18,Amsterdam_RP-D-2017-1871,Amsterdam_RP-D-2017-1745,Amsterdam_RP-D-2017-1796,Amsterdam_RP-D-2017-1852,Amsterdam_RP-D-2017-1876,Amsterdam_RP-D-2017-1702,Amsterdam_RP-D-1982-43-HADKINSON(E.)-22A,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-10,Amsterdam_RP-D-2017-1705,Amsterdam_RP-D-2017-1761,Amsterdam_RP-D-2017-1792,Amsterdam_RP-D-1982-43-DUCHATTEL-2,Amsterdam_RP-D-1982-43-GUROWSKI(CH.)-1,Amsterdam_RP-D-1982-43-EEKHOUD(G.)-6,Amsterdam_RP-D-1982-43-GUERARD(H.)-5,Amsterdam_RP-D-2017-1773,Amsterdam_RP-D-1982-43-HUYSMANS(J.K.)-2,Amsterdam_RP-D-1982-43-AVERY-29,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-18,Amsterdam_RP-D-1982-43-BEATTY-2,Amsterdam_RP-D-1982-43-KARSEN(E.)-23,Amsterdam_RP-D-1982-43-AVERY-79,Amsterdam_RP-D-2017-1791,Amsterdam_RP-D-2017-1763,Amsterdam_RP-D-1982-43-HAAXMAN(P.A.)-2,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-6,Amsterdam_RP-D-1982-43-GUERARD(H.)-4,Amsterdam_RP-D-1982-43-ERLICH(J.)-22,Amsterdam_RP-D-2017-1854,Amsterdam_RP-D-2017-1806,Amsterdam_RP-D-1982-43-HADKINSON(E.)-14,Amsterdam_RP-D-2017-1802,Amsterdam_RP-D-1982-43-PICA(A.)-42A,Amsterdam_RP-D-2017-1704,Amsterdam_RP-D-1982-43-ERLICH(J.)-15,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-1,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-25,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-12,Amsterdam_RP-D-2017-1923,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-2,Amsterdam_RP-D-1982-43-EEKHOUD(G.)-8,Amsterdam_RP-D-1982-43-HADKINSON(E.)-11A,Amsterdam_RP-D-1982-43-HADKINSON(E.)-17B,Amsterdam_RP-D-2017-1822,Amsterdam_RP-D-1982-43-GUERARD(H.)-DOC.1,Amsterdam_RP-D-1982-43-PICA3-68,Amsterdam_RP-D-2017-1746,Amsterdam_RP-D-2017-1673,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-24,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-14B,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-4,Amsterdam_RP-D-1982-43-PICA3-51,Amsterdam_RP-D-1982-43-ERENS(F.)-7,Amsterdam_RP-D-2017-1739,Amsterdam_RP-D-2017-1712,Amsterdam_RP-D-2017-1757,Amsterdam_RP-D-2017-1709,Amsterdam_RP-D-2017-1872,Amsterdam_RP-D-2017-1727,Amsterdam_RP-D-2017-1820,Amsterdam_RP-D-2017-1711,Amsterdam_RP-D-1982-43-PICA-92,Amsterdam_RP-D-2017-1830,Amsterdam_RP-D-2017-1811,Amsterdam_RP-D-2017-1809,Amsterdam_RP-D-2017-1799,Amsterdam_RP-D-2017-1784,Amsterdam_RP-D-2017-1703,Amsterdam_RP-D-1982-43-PICA(V-A)-42C,Amsterdam_RP-D-1982-43-PICA3-47,Amsterdam_RP-D-1982-43-PICA3-52,Amsterdam_RP-D-1982-43-PICA-85,Amsterdam_RP-D-2017-2116,Amsterdam_RP-D-2017-2106,Amsterdam_RP-D-2017-2132,Amsterdam_RP-D-2017-2101,Amsterdam_RP-D-2017-2134,Amsterdam_RP-D-1982-43-PICA-87,Amsterdam_RP-D-2017-2166,Amsterdam_RP-D-2017-2067,Amsterdam_RP-D-1982-43-PICA-42B,Amsterdam_RP-D-2017-2140,Amsterdam_RP-D-2017-2164,Amsterdam_RP-D-1982-43-PICA3-46,Amsterdam_RP-D-1982-43-PICA3-62,Amsterdam_RP-D-2017-2084,Amsterdam_RP-D-2017-2157,Amsterdam_RP-D-2017-2127,Amsterdam_RP-D-1982-43-PICA-88,Amsterdam_RP-D-2017-2114,Amsterdam_RP-D-1982-43-PICA-43B,Amsterdam_RP-D-2017-2103,Amsterdam_RP-D-2017-2092,Amsterdam_RP-D-2017-2109,Amsterdam_RP-D-2017-2137,Amsterdam_RP-D-2017-2147,Amsterdam_RP-D-2017-2082,Amsterdam_RP-D-2017-2105,Amsterdam_RP-D-2017-2112,Amsterdam_RP-D-2017-2098,Amsterdam_RP-D-2017-2146,Amsterdam_RP-D-2017-2125,Amsterdam_RP-D-2017-2158,Amsterdam_RP-D-1982-43-PICA-89,Amsterdam_RP-D-2017-2066,Amsterdam_RP-D-2017-2097,Amsterdam_RP-D-2017-2090,Amsterdam_RP-D-2017-2100,Amsterdam_RP-D-2017-2142,Amsterdam_RP-D-2017-2133,Amsterdam_RP-D-2017-2169,Amsterdam_RP-D-2017-2135,Amsterdam_RP-D-1982-43-AVERY-71,Amsterdam_RP-D-2017-2160,Amsterdam_RP-D-1982-43-A.DAYOT-1,Amsterdam_RP-D-1982-43-AVERY-72,Amsterdam_RP-D-1982-43-AVERY-60,Amsterdam_RP-D-1982-43-AVERY-65,Amsterdam_RP-D-2017-2168,Amsterdam_RP-D-2017-2096,Amsterdam_RP-D-1982-43-E.DEMOLDER-1,Amsterdam_RP-D-1982-43-AVERY-48,Amsterdam_RP-D-1982-43-A.DELATRE-1,Amsterdam_RP-D-2017-2124,Amsterdam_RP-D-2017-2086,Amsterdam_RP-D-2017-2083,Amsterdam_RP-D-2017-2148,Amsterdam_RP-D-2017-2115,Amsterdam_RP-D-2017-2122,Amsterdam_RP-D-1982-43-A.DELZANT-1,Amsterdam_RP-D-1982-43-BEATTY-4,Amsterdam_RP-D-1982-43-A.DAUDET-1,Amsterdam_RP-D-1982-43-AVERY-53,Amsterdam_RP-D-1982-43-HUNT-2,Amsterdam_RP-D-1982-43-FRAPPA(J.J.)-1,Amsterdam_RP-D-1982-43-FRANDSEN(D.)-14B,Amsterdam_RP-D-1982-43-FONTAINAS(A.)-1,Amsterdam_RP-D-1982-43-AVERY-81,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-5A,Amsterdam_RP-D-1982-43-AVERY-70,Amsterdam_RP-D-1982-43-AVERY-75,Amsterdam_RP-D-1982-43-AVERY-44,Amsterdam_RP-D-1982-43-BEATTY-3,Amsterdam_RP-D-1982-43-KLOPPERS(H.)-1,Amsterdam_RP-D-1982-43-AVERY-58,Amsterdam_RP-D-2017-1939,Amsterdam_RP-D-1982-43-KLINKENBERG(K.)-2,Amsterdam_RP-D-1982-43-MANSFIELD-3,Amsterdam_RP-D-1982-43-M.BIERME-8,Amsterdam_RP-D-1982-43-FORTUNY-MADRAZO-3,Amsterdam_RP-D-1982-43-EVENO-1,Amsterdam_RP-D-1982-43-AVERY-76,Amsterdam_RP-D-1982-43-BEATTY-1,Amsterdam_RP-D-1982-43-AVERY-66,Amsterdam_RP-D-1982-43-AVERY-68,Amsterdam_RP-D-2017-2034,Amsterdam_RP-D-2017-2022,Amsterdam_RP-D-1982-43-AVERY-49,Amsterdam_RP-D-1982-43-MANSFIELD-2,Amsterdam_RP-D-2017-2044,Amsterdam_RP-D-2017-1978,Amsterdam_RP-D-1982-43-AVERY-26,Amsterdam_RP-D-1982-43-AVERY-69,Amsterdam_RP-D-1982-43-BEATTY-5,Amsterdam_RP-D-1982-43-M.BIERME-10,Amsterdam_RP-D-1982-43-AVERY-77,Amsterdam_RP-D-2017-1985,Amsterdam_RP-D-1982-43-M.DENIS-4,Amsterdam_RP-D-1982-43-AVERY-82,Amsterdam_RP-D-1982-43-O.G.DESTREE-3,Amsterdam_RP-D-1982-43-AVERY-74,Amsterdam_RP-D-1982-43-O.G.DESTREE-2,Amsterdam_RP-D-2017-1847,Amsterdam_RP-D-1982-43-A.DELAHERCHE-1,Amsterdam_RP-D-1982-43-HUNT-1,Amsterdam_RP-D-1982-43-AVERY-67,Amsterdam_RP-D-1982-43-A.DEMONT-1,Amsterdam_RP-D-2017-2025,Amsterdam_RP-D-2017-1962,Amsterdam_RP-D-1982-43-L.VANDELDEN-1,Amsterdam_RP-D-1982-43-A.DEMONT-3,Amsterdam_RP-D-1982-43-AVERY-59,Amsterdam_RP-D-1982-43-AVERY-42,Amsterdam_RP-D-2017-2006,Amsterdam_RP-D-2017-1982,Amsterdam_RP-D-2017-1946,Amsterdam_RP-D-1982-43-A.DAYOT-2,Amsterdam_RP-D-2017-1848,Amsterdam_RP-D-2017-2037,Amsterdam_RP-D-2017-1902,Amsterdam_RP-D-2017-2015,Amsterdam_RP-D-2017-1900,Amsterdam_RP-D-2017-2049,Amsterdam_RP-D-2017-1894,Amsterdam_RP-D-2017-1984,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-6,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-4,Amsterdam_RP-D-1982-43-KARSEN(ED.)-71,Amsterdam_RP-D-1982-43-GASKIN(ARTHUR.J.)-1,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-14,Amsterdam_RP-D-1982-43-GASKIN(ARTHUR.J.)-4,Amsterdam_RP-D-1982-43-KARSEN(ED.)-46,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-31,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-26,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-16,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-5,Amsterdam_RP-D-1982-43-GEUL(J.)-3,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-20,Amsterdam_RP-D-1984-40-A.JOLLES-25,Amsterdam_RP-D-2016-6-153,Amsterdam_RP-D-2016-6-148,Amsterdam_RP-D-1982-43-FELIX-FENEON-12,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-7,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-4B,Amsterdam_RP-D-1982-43-FELIX-FENEON-9,Amsterdam_RP-D-2017-1938,Amsterdam_RP-D-2017-2047,Amsterdam_RP-D-2017-1966,Amsterdam_RP-D-2017-2038,Amsterdam_RP-D-00-1071,Amsterdam_RP-D-2017-2012,Amsterdam_RP-D-2017-2003,Amsterdam_RP-D-2017-1968,Amsterdam_RP-D-2017-2055,Amsterdam_RP-D-2017-1913,Amsterdam_RP-D-2017-2035,Amsterdam_RP-D-2017-1944,Amsterdam_RP-D-2017-1986,Amsterdam_RP-D-2017-2011,Amsterdam_RP-D-2017-1973,Amsterdam_RP-D-2017-1943,Amsterdam_RP-D-00-1069,Amsterdam_RP-D-00-1070,Amsterdam_RP-D-2017-1904,Amsterdam_RP-D-2017-2053,Amsterdam_RP-D-2017-2024,Amsterdam_RP-D-2017-1974,Amsterdam_RP-D-2017-1910,Amsterdam_RP-D-2017-1937,Amsterdam_RP-D-1982-43-ERENS(F.)-4,Amsterdam_RP-D-1982-43-ERLICH(J.)-28,Amsterdam_RP-D-1982-43-ENSOR(JAMES)-3,Amsterdam_RP-D-1982-43-GUROWSKI(CH.)-2,Amsterdam_RP-D-1982-43-ENSOR(JAMES)-1,Amsterdam_RP-D-1982-43-HUYSMANS(J.K.)-1,Amsterdam_RP-D-1982-43-GUIMET(E.)-1,Amsterdam_RP-D-1982-43-HUYGENS(J.)-1,Amsterdam_RP-D-1982-43-HADKINSON(E.)-11B,Amsterdam_RP-D-1982-43-HAAXMAN(P.A.)-1,Amsterdam_RP-D-2017-2408,Amsterdam_RP-D-2017-2431,Amsterdam_RP-D-2017-2396,Amsterdam_BI-1950-17-106,Amsterdam_BI-1950-17-116,Amsterdam_RP-D-2017-2444,Amsterdam_RP-D-2017-2373,Amsterdam_RP-D-2017-2409,Amsterdam_RP-D-1981-21,Amsterdam_RP-D-2017-2343,Amsterdam_BI-1950-17-1,Amsterdam_BI-1950-17-56,Amsterdam_RP-D-2017-2331,Amsterdam_BI-1950-17-72,Amsterdam_BI-1950-17-60,Amsterdam_BI-1950-17-31,Amsterdam_BI-1950-17-77,Amsterdam_BI-1950-17-16,Amsterdam_RP-D-R.N.ROLANDHOLST-104,Amsterdam_RP-D-BACKHUYSEN.G.-4,Amsterdam_RP-D-2017-2319,Amsterdam_RP-D-2017-2335,Amsterdam_RP-D-1982-43-J.COMTE-6,Amsterdam_RP-D-1982-43-J.DESTREE-4,Amsterdam_RP-D-1982-43-P.ALFANA-5,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-85,Amsterdam_RP-D-1982-43-CLAPIER-H.-7,Amsterdam_RP-D-1982-43-JURRES(J.H.)-1,Amsterdam_RP-D-1982-43-GODOY(A.)-2,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-100,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-95,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-104,Amsterdam_RP-D-1982-43-J.COMTE-9,Amsterdam_RP-D-2017-1483,Amsterdam_RP-D-DR.SCHAEPMAN-3,Amsterdam_RP-D-MOUILLERON.A-6,Amsterdam_RP-D-1982-43-GRANTKINGORE(H.)-1,Amsterdam_RP-D-1982-43-DESLANDES-13,Amsterdam_RP-D-1982-43-H.BERALDI-3,Amsterdam_RP-D-DR.SCHAEPMAN-22,Amsterdam_RP-D-MOUILLERON.A-44,Amsterdam_RP-D-1982-43-H.L.BERCKENHOFF-5,Amsterdam_RP-D-2017-1453,Amsterdam_RP-D-2017-1350,Amsterdam_RP-D-1982-43-L.BENEDITE-4,Amsterdam_RP-D-1982-43-GRAM(J.)-8,Amsterdam_RP-D-2017-1365,Amsterdam_RP-D-MOUILLERON.A-49,Amsterdam_RP-D-2017-1534,Amsterdam_RP-D-1982-43-DESLANDES-6,Amsterdam_RP-D-2017-1469,Amsterdam_RP-D-2017-1559,Amsterdam_RP-D-2017-1549,Amsterdam_RP-D-2017-1488,Amsterdam_RP-D-MOUILLERON.A.-9,Amsterdam_RP-D-2017-1651,Amsterdam_RP-D-1982-43-GRAM(J.)-6,Amsterdam_RP-D-2017-1423,Amsterdam_RP-D-1982-43-GONSE(L.)-4,Amsterdam_RP-D-1982-43-104,Amsterdam_RP-D-1982-43-113,Amsterdam_RP-D-1982-43-246,Amsterdam_RP-D-1982-43-HORST-ZILCKEN-20,Amsterdam_RP-D-1982-43-NIJS-1,Amsterdam_RP-D-1982-43-214,Amsterdam_RP-D-1982-43-162,Amsterdam_RP-D-1982-43-150,Amsterdam_RP-D-1982-43-133,Amsterdam_RP-D-1982-43-DEJONGVB.ED-5,Amsterdam_RP-D-1982-43-209,Amsterdam_RP-D-1982-43-132,Amsterdam_RP-D-1982-43-117,Amsterdam_RP-D-1982-43-217,Amsterdam_RP-D-1982-43-234,Amsterdam_RP-D-1982-43-137,Amsterdam_RP-D-1982-43-111,Amsterdam_RP-D-1982-43-152,Amsterdam_RP-D-1982-43-161,Amsterdam_RP-D-1982-43-252,Amsterdam_RP-D-1982-43-93,Amsterdam_RP-D-1982-43-138,Amsterdam_RP-D-1982-43-98,Amsterdam_RP-D-1982-43-134,Amsterdam_RP-D-1982-43-147,Amsterdam_RP-D-1982-43-251,Amsterdam_RP-D-1982-43-107,Amsterdam_RP-D-1982-43-114,Amsterdam_RP-D-1982-43-242,Amsterdam_RP-D-1982-43-248,Amsterdam_RP-D-1982-43-219,Amsterdam_RP-D-1982-43-240,Amsterdam_RP-D-1982-43-247,Amsterdam_RP-D-1982-43-221,Amsterdam_RP-D-1982-43-212,Amsterdam_RP-D-1982-43-253,Amsterdam_RP-D-1982-43-115,Amsterdam_RP-D-1982-43-146,Amsterdam_RP-D-1982-43-206,Amsterdam_RP-D-1982-43-233,Amsterdam_RP-D-1982-43-141,Amsterdam_RP-D-1982-43-249,Amsterdam_RP-D-1982-43-166,Amsterdam_RP-D-1982-43-213,Amsterdam_RP-D-1982-43-131,Amsterdam_RP-D-1982-43-148,Amsterdam_RP-D-1982-43-218,Amsterdam_RP-D-1982-43-97,Amsterdam_RP-D-1982-43-236,Amsterdam_RP-D-1982-43-92,Amsterdam_RP-D-1982-43-222,Amsterdam_RP-D-1982-43-208,Amsterdam_RP-D-1982-43-215,Amsterdam_RP-D-1982-43-223,Amsterdam_RP-D-1982-43-220,Amsterdam_RP-D-1982-43-119,Amsterdam_RP-D-1982-43-130,Amsterdam_RP-D-1982-43-238,Amsterdam_RP-D-1982-43-143,Amsterdam_RP-D-1982-43-167,Amsterdam_RP-D-1982-43-109,Amsterdam_RP-D-1982-43-256,Amsterdam_RP-D-1982-43-129,Amsterdam_RP-D-1982-43-245,Amsterdam_RP-D-1982-43-DEJONGV.BED.-2,Amsterdam_RP-D-1982-43-165,Amsterdam_RP-D-1982-43-231,Amsterdam_RP-D-1982-43-ANDRE(H.)-1,Amsterdam_RP-D-1982-43-FRANKAMP-1,Amsterdam_RP-D-1982-43-168,Amsterdam_RP-D-1982-43-239,Amsterdam_RP-D-1982-43-211,Amsterdam_RP-D-1982-43-118,Amsterdam_RP-D-1982-43-228,Amsterdam_RP-D-1982-43-244,Amsterdam_RP-D-1982-43-96,Amsterdam_RP-D-1982-43-136,Amsterdam_RP-D-1982-43-250,Amsterdam_RP-D-1982-43-106,Amsterdam_RP-D-1982-43-227,Amsterdam_RP-D-1982-43-316,Amsterdam_RP-D-1982-43-434,Amsterdam_RP-D-1982-43-353,Amsterdam_RP-D-1982-43-260,Amsterdam_RP-D-1982-43-389,Amsterdam_RP-D-1982-43-455,Amsterdam_RP-D-1982-43-315,Amsterdam_RP-D-1982-43-362,Amsterdam_RP-D-1982-43-444,Amsterdam_RP-D-1982-43-435,Amsterdam_RP-D-1982-43-317,Amsterdam_RP-D-1982-43-462,Amsterdam_RP-D-1982-43-319,Amsterdam_RP-D-1982-43-440,Amsterdam_RP-D-1982-43-418,Amsterdam_RP-D-1982-43-386,Amsterdam_RP-D-1982-43-393,Amsterdam_RP-D-1982-43-400,Amsterdam_RP-D-1982-43-385,Amsterdam_RP-D-1982-43-421,Amsterdam_RP-D-1982-43-442,Amsterdam_RP-D-1982-43-467,Amsterdam_RP-D-1982-43-405,Amsterdam_RP-D-1982-43-414,Amsterdam_RP-D-1982-43-410,Amsterdam_RP-D-1982-43-433,Amsterdam_RP-D-1982-43-318,Amsterdam_RP-D-1982-43-380,Amsterdam_RP-D-1982-43-403,Amsterdam_RP-D-1982-43-374,Amsterdam_RP-D-1982-43-419,Amsterdam_RP-D-1982-43-270,Amsterdam_RP-D-1982-43-463,Amsterdam_RP-D-1982-43-392,Amsterdam_RP-D-1982-43-461,Amsterdam_RP-D-1982-43-445,Amsterdam_RP-D-1982-43-375,Amsterdam_RP-D-1982-43-394,Amsterdam_RP-D-1982-43-402,Amsterdam_RP-D-1982-43-379,Amsterdam_RP-D-1982-43-397,Amsterdam_RP-D-1982-43-423,Amsterdam_RP-D-1982-43-447,Amsterdam_RP-D-1982-43-377,Amsterdam_RP-D-1982-43-387,Amsterdam_RP-D-1982-43-381,Amsterdam_RP-D-1982-43-425,Amsterdam_RP-D-1982-43-401,Amsterdam_RP-D-1982-43-396,Amsterdam_RP-D-1982-43-424,Amsterdam_RP-D-1982-43-460,Amsterdam_RP-D-1982-43-454,Amsterdam_RP-D-1982-43-404,Amsterdam_RP-D-1982-43-443,Amsterdam_RP-D-1982-43-388,Amsterdam_RP-D-1982-43-432,Amsterdam_RP-D-1982-43-422,Amsterdam_RP-D-1982-43-449,Amsterdam_RP-D-1982-43-412,Amsterdam_RP-D-1982-43-407,Amsterdam_RP-D-1982-43-456,Amsterdam_RP-D-1982-43-408,Amsterdam_RP-D-1982-43-458,Amsterdam_RP-D-2017-2470,Amsterdam_RP-D-1982-43-MOUREY(G.)-13,Amsterdam_RP-D-1982-43-MONNICKENDAM(M.)-1,Amsterdam_RP-D-2017-2452-48,Amsterdam_RP-D-2017-2562,Amsterdam_RP-D-2017-2564,Amsterdam_RP-D-2017-2543,Amsterdam_RP-D-2017-2516,Amsterdam_RP-P-1970-415,Amsterdam_BI-1950-17-650,Amsterdam_BI-1950-17-646,Amsterdam_RP-D-2017-2594,Amsterdam_RP-D-2017-2452-451,Amsterdam_RP-D-1982-43-MISTRAL(F.)-5,Amsterdam_RP-D-1982-43-MEUNIER(JB)-1,Amsterdam_RP-D-2017-2593,Amsterdam_RP-D-1982-43-LOUDON(L.)-1,Amsterdam_RP-D-1982-43-MISTRAL(F.)-4,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-5,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-8,Amsterdam_RP-D-1982-43-LOUDON(J.)-6,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-2,Amsterdam_RP-D-1982-43-MEUNIER(H.)-1,Amsterdam_RP-D-1982-43-MOULIJN(S.)-4,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-3,Amsterdam_RP-D-1982-43-MISTRAL(F.)-6,Amsterdam_RP-D-1982-43-MISTRAL(F.)-2,Amsterdam_RP-D-1982-43-MOULIJN(S.)-2,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-11,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-1,Amsterdam_RP-D-1982-43-MOES(E.W.)-3,Amsterdam_RP-D-1982-43-MOULIJN(S.)-6,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-10,Amsterdam_RP-D-1982-43-METZ-KONING(M.)-4,Amsterdam_RP-D-1982-43-E.DETAILLE-1,Amsterdam_RP-D-1982-43-DONATO-1,Amsterdam_RP-D-1982-43-A.BAERTSOEN-3,Amsterdam_RP-D-1982-43-DHAYRMOND-1,Amsterdam_RP-D-1982-43-A.BAERTSOEN-25,Amsterdam_RP-D-1982-43-DREVETON-1,Amsterdam_RP-D-1982-43-DESTUERS-4,Amsterdam_RP-D-1982-43-A.BAERTSOEN-2,Amsterdam_RP-D-1982-43-C.TH.VANDEVENTER-1,Amsterdam_RP-D-1982-43-A.BAERTSOEN-8,Amsterdam_RP-D-1982-43-A.BAERTSOEN-5,Amsterdam_RP-D-1982-43-ODILON-5,Amsterdam_RP-D-1982-43-DESTUERS-2,Amsterdam_RP-D-1982-43-A.BAERTSOEN-7,Amsterdam_RP-D-1982-43-ODILON-4,Amsterdam_RP-D-1982-43-ODILON-1,Amsterdam_RP-D-1982-43-DARIODEREGOYOS-5,Amsterdam_RP-D-1982-43-ODILON-3,Amsterdam_RP-D-1982-43-ODILON-6,Amsterdam_RP-D-1982-43-DARIODEREGOYOS-3,Amsterdam_RP-D-1982-43-DESTUERS(V.)-DOC.2,Amsterdam_RP-D-1981-18,Amsterdam_RP-D-1982-43-DELALAURENCIE(L.)-2,Amsterdam_RP-D-1982-43-DARIODEREGOYOS-4,Amsterdam_RP-D-1982-43-DESTUERS(V.)-1,Amsterdam_RP-D-2017-1563,Amsterdam_RP-D-2017-1388,Amsterdam_RP-D-2017-1375,Amsterdam_RP-D-1982-41A,Amsterdam_RP-D-DR.SCHAEPMAN-16,Amsterdam_RP-D-2017-1380,Amsterdam_RP-D-DR.SCHAEPMAN-6,Amsterdam_RP-D-2017-1662,Amsterdam_RP-D-MOUILLERON.A-40,Amsterdam_RP-D-2017-1418,Amsterdam_RP-D-2017-1376,Amsterdam_RP-D-MOUILLERON.A-29,Amsterdam_RP-D-2017-1359,Amsterdam_RP-D-2017-1428,Amsterdam_RP-D-2017-654,Amsterdam_RP-D-2017-1637,Amsterdam_RP-D-DR.SCHAEPMAN-23,Amsterdam_RP-D-MOUILLERON.A-14,Amsterdam_RP-D-2017-1656,Amsterdam_RP-D-DR.SCHAEPMAN-11,Amsterdam_RP-D-2017-1452,Amsterdam_RP-D-2017-1565,Amsterdam_RP-D-2017-1467,Amsterdam_RP-D-1982-43-GONSE(L.)-1,Amsterdam_RP-D-1982-43-DESLANDES-1,Amsterdam_RP-D-1982-43-E.DESHAYES-1,Amsterdam_RP-D-2017-1550,Amsterdam_RP-D-1905-94,Amsterdam_RP-D-1981-11,Amsterdam_RP-D-1982-43-A.BOUVENNE-4,Amsterdam_RP-D-1982-43-H.L.BERCKENHOFF-1,Amsterdam_RP-D-1982-43-DESLANDES-33,Amsterdam_RP-D-2017-1600,Amsterdam_RP-D-1982-43-L.BENEDITE-36,Amsterdam_RP-D-2017-1604,Amsterdam_RP-D-2017-1529,Amsterdam_RP-D-2017-1528,Amsterdam_RP-D-2017-1518,Amsterdam_RP-D-1982-43-GRAM(J.)-1,Amsterdam_RP-D-MOUILLERON.A-16,Amsterdam_RP-D-1982-43-DESLANDES-12,Amsterdam_RP-D-DR.SCHAEPMAN-7,Amsterdam_RP-D-2017-1533,Amsterdam_RP-D-1982-43-L.BENEDITE-16,Amsterdam_RP-D-1982-43-L.BENEDITE-24,Amsterdam_RP-D-1982-43-M.DESBOUTINS-3,Amsterdam_RP-D-1982-43-J.DESBOIS-1,Amsterdam_RP-D-MOUILLERON.A-27,Amsterdam_RP-D-1982-43-A.BOUVENNE-2,Amsterdam_RP-D-1982-43-HADKINSON(E.)-1A,Amsterdam_RP-D-1982-43-GONSE(L.)-2,Amsterdam_RP-D-1982-43-HADKINSON(E.)-3B,Amsterdam_RP-D-1982-43-L.BENEDITE-5,Amsterdam_RP-D-1982-43-DESLANDES-27,Amsterdam_RP-D-1982-43-L.BENEDITE-48,Amsterdam_RP-D-1981-16,Amsterdam_RP-D-1982-43-HAMERTON(P.G.)-4,Amsterdam_RP-D-1982-43-L.BENEDITE-10,Amsterdam_RP-D-1982-43-L.BENEDITE-20,Amsterdam_RP-D-1907-89,Amsterdam_RP-D-1982-43-H.L.BERCKENHOFF-2,Amsterdam_RP-D-1982-43-GONSE(L.)-3,Amsterdam_RP-D-1982-43-L.BENEDITE-43,Amsterdam_RP-D-1982-43-A.BOUVENNE-1,Amsterdam_RP-D-1982-43-DESLANDES-26B,Amsterdam_RP-D-1982-43-DESLANDES-2,Amsterdam_RP-D-1982-43-DESLANDES-3,Amsterdam_RP-D-1982-43-GRAM(J.)-2,Amsterdam_RP-D-1982-43-H.BERALDI-2,Amsterdam_RP-D-1981-13,Amsterdam_RP-D-1982-43-HADKINSON(E.)-1B,Amsterdam_RP-D-1982-43-DESLANDES-29A,Amsterdam_RP-D-1982-43-DESLANDES-10,Amsterdam_RP-D-1982-43-DESLANDES-11,Amsterdam_RP-D-1982-43-GRAM(J.)-5,Amsterdam_RP-D-1982-43-L.BENEDITE-30,Amsterdam_RP-D-1982-43-M.DESBOUTINS-1,Amsterdam_RP-D-1982-43-DESLANDES-30,Amsterdam_RP-D-1982-43-DESLANDES-28,Amsterdam_RP-D-1982-43-H.L.BERCKENHOFF-6,Amsterdam_BI-1950-17-764,Amsterdam_BI-1950-17-465,Amsterdam_RP-D-2017-2285-B,Amsterdam_BI-1950-17-502,Amsterdam_BI-1950-17-559,Amsterdam_BI-1950-17-473,Amsterdam_BI-1950-17-513,Amsterdam_BI-1950-17-535,Amsterdam_BI-1950-17-498,Amsterdam_BI-1950-17-574,Amsterdam_BI-1950-17-512,Amsterdam_BI-1950-17-493,Amsterdam_BI-1950-17-566,Amsterdam_BI-1950-17-518,Amsterdam_BI-1950-17-553,Amsterdam_BI-1950-17-564,Amsterdam_BI-1950-17-532,Amsterdam_BI-1950-17-570,Amsterdam_BI-1950-17-481,Amsterdam_BI-1950-17-555,Amsterdam_BI-1950-17-486,Amsterdam_BI-1950-17-507,Amsterdam_BI-1950-17-556,Amsterdam_BI-1950-17-496,Amsterdam_BI-1950-17-558,Amsterdam_BI-1950-17-508,Amsterdam_BI-1950-17-489,Amsterdam_BI-1950-17-495,Amsterdam_BI-1950-17-522,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-4,Amsterdam_RP-D-1982-43-LIMBURG-CLANT-2,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-81,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-6,Amsterdam_RP-D-1982-43-LUMIERE(ANTOINE)-2,Amsterdam_RP-D-1982-43-LEPERE(A.)-5,Amsterdam_RP-D-1982-43-LION(J.M.)-1,Amsterdam_RP-D-1982-43-LAPIDOTH(F.)-2,Amsterdam_RP-D-1982-43-LEPERE(A.)-16,Amsterdam_RP-D-1982-43-LEPERE(A.)-11,Amsterdam_RP-D-1982-43-LIMBURG-CLANT-3,Amsterdam_RP-D-1982-43-LEPERE(A.)-1,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-98,Amsterdam_RP-D-1982-43-LEPERE(A.)-2,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-95,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-5,Amsterdam_RP-D-1982-43-LEPERE(A.)-13,Amsterdam_RP-D-1982-43-IMEL-168,Amsterdam_RP-D-1982-43-MERTENS(CH.)-2,Amsterdam_RP-D-1982-43-IMEL-171,Amsterdam_RP-D-1982-43-LEPERE(A.)-6,Amsterdam_RP-D-1982-43-LOFFELT(A.C.)-2,Amsterdam_RP-D-1982-43-LIMBURG-CLANT(1),Amsterdam_RP-D-1982-43-IMEL-166,Amsterdam_RP-D-1982-43-LEPERE(A.)-12,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-87,Amsterdam_RP-D-1982-43-HIMELSCHEIN-52,Amsterdam_RP-D-1982-43-MELLERY(X.)-1,Amsterdam_RP-D-1982-43-LEPERE(A.)-7,Amsterdam_RP-D-1982-43-LEPERE(A.)-3,Amsterdam_RP-D-1982-43-LOISEL(DR.T)-1,Amsterdam_RP-D-1982-43-LEPERE(A.)-18,Amsterdam_RP-D-1982-43-IMEL-167,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-3,Amsterdam_RP-D-1982-43-MERTENS(CH.)-3,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-7,Amsterdam_RP-D-1982-43-LINSEN(BETSY)-1,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-19,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-97,Amsterdam_RP-D-1982-43-LEPERE(A.)-4B,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-1,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-79,Amsterdam_RP-D-1982-43-LUNS(HUIB)-1,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-71,Amsterdam_RP-D-1982-43-LUMIERE(ANTOINE)-1,Amsterdam_RP-D-1982-43-LEPERE(A.)-17,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-89,Amsterdam_RP-D-1982-43-LEPERE(A.)-15,Amsterdam_RP-D-1982-43-LEPERE(A.)-14,Amsterdam_RP-D-1982-43-LEPERE(A.)-9,Amsterdam_RP-D-1982-43-LEPERE(A.)-8A,Amsterdam_RP-D-1982-43-LEPERE(A.)-4A,Amsterdam_RP-D-1982-43-LIPPING(E.)-1,Amsterdam_RP-D-1982-43-LYTA(LYDIA)-1,Amsterdam_RP-D-1982-43-MENDESDACOSTA-4,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-80,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-102,Amsterdam_RP-D-1982-43-MESDAG-V.CALCAR-1,Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-2,Amsterdam_RP-D-1982-43-LEPERE(A.)-10,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-73,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-105,Amsterdam_RP-D-1982-43-LAPIDOTH(F.)-5,Amsterdam_RP-T-1883-A-283-6-B,Amsterdam_RP-T-2004-103-30(V),Amsterdam_NG-2017-88,Amsterdam_NG-2017-86,Amsterdam_NG-2017-89,Amsterdam_RP-D-1982-43-158,Amsterdam_RP-D-1982-43-243,Amsterdam_RP-D-1982-43-95,Amsterdam_RP-D-1982-43-216,Amsterdam_RP-D-1982-43-157,Amsterdam_RP-D-1982-43-91,Amsterdam_RP-D-1982-43-120,Amsterdam_RP-D-1982-43-235,Amsterdam_RP-D-1982-43-163,Amsterdam_RP-D-1982-43-160,Amsterdam_RP-D-1982-43-DONRESCALLI-3A,Amsterdam_RP-D-1982-43-230,Amsterdam_RP-D-1982-43-135,Amsterdam_RP-D-1982-43-241,Amsterdam_RP-D-1982-43-232,Amsterdam_RP-D-1981-10,Amsterdam_RP-D-2017-140,Amsterdam_RP-D-1907-84,Amsterdam_RP-D-1980-5,Amsterdam_RP-T-1969-941(V),Amsterdam_RP-D-1980-6,Amsterdam_RP-D-1982-43-F.BRACQUEMOND-3,Amsterdam_RP-D-1982-43-M.BAUER-4,Amsterdam_RP-D-1982-43-A.BREDIUS-42,Amsterdam_RP-D-1982-43-M.BAUER-27,Amsterdam_RP-D-1982-43-M.BAUER-85,Amsterdam_RP-D-1982-43-F.BUHOT-4,Amsterdam_RP-D-1982-43-M.BAUER-58,Amsterdam_RP-D-1982-43-M.BAUER-118,Amsterdam_RP-D-1982-43-A.BREDIUS-56,Amsterdam_RP-D-1982-43-A.BREDIUS-76,Amsterdam_RP-D-1982-43-M.BAUER-28,Amsterdam_RP-D-1982-43-A.BREDIUS-63,Amsterdam_RP-D-1982-43-DEWILD-10,Amsterdam_RP-D-1982-43-DEWILD-1,Amsterdam_RP-D-1982-43-DEWILD-11,Amsterdam_RP-D-1982-43-DEWILD-8,Amsterdam_RP-D-1982-43-DEWILD-3,Amsterdam_RP-D-1982-43-DEWILD-5,Amsterdam_RP-D-1982-43-DEWILD-4,Amsterdam_RP-D-1982-43-DEWILD-12,Amsterdam_RP-D-1982-43-PICA-140,Amsterdam_RP-D-1982-43-A.PIT-140,Amsterdam_RP-D-1982-43-DEWILD-9,Amsterdam_RP-D-1982-43-DEWILD-2,Amsterdam_RP-D-1982-43-DEWILD-7,Amsterdam_RP-D-2017-2452-49,Amsterdam_BI-1950-17-675,Amsterdam_RP-P-OB-17.536,Amsterdam_RP-D-2017-2452-51,Amsterdam_RP-D-1982-43-PASCHAL(L.)-5A,Amsterdam_RP-D-1982-43-OPPENOORT(W.J.)-3,Amsterdam_RP-D-1982-43-DENYON(F.)-1,Amsterdam_RP-D-2017-2452-52,Amsterdam_RP-D-2017-2452-54,Amsterdam_RP-D-1982-43-MOUREY(G.)-3,Amsterdam_BI-1950-17-654,Amsterdam_RP-D-1982-43-MALLARME(S.)-8BB,Amsterdam_RP-D-1982-43-MULLER(W.)-1A,Amsterdam_RP-D-1982-43-PANDER(PIER)-1,Amsterdam_RP-D-1982-43-NIFTRIK(C.H.J.)-1,Amsterdam_RP-D-1982-43-MOUTON-1,Amsterdam_BI-1950-17-645,Amsterdam_RP-D-1982-43-MALLARME(S.)-9,Amsterdam_RP-D-1982-43-OFFERMANS(T.)-6,Amsterdam_RP-D-1982-43-NETSCHER(F.)-2,Amsterdam_RP-D-1982-43-MOUREY(G.)-1,Amsterdam_RP-D-1982-43-MULLER(WIM)-2B,Amsterdam_RP-D-1982-43-MOUREY(G.)-9,Amsterdam_BI-1950-17-638,Amsterdam_BI-1950-17-647,Amsterdam_BI-1950-17-762,Amsterdam_RP-D-1981-8,Amsterdam_BI-1950-17-755,Amsterdam_RP-D-1980-59-43,Amsterdam_RP-D-2017-2199,Amsterdam_RP-D-2017-2231,Amsterdam_RP-D-1980-59-71,Amsterdam_RP-D-1980-59-36,Amsterdam_RP-D-1980-59-81,Amsterdam_RP-D-1980-59-74,Amsterdam_RP-D-1980-59-68,Amsterdam_RP-D-1980-59-37,Amsterdam_RP-D-1980-59-52,Amsterdam_RP-D-1980-59-38,Amsterdam_RP-D-1980-59-41,Amsterdam_RP-D-1980-59-73,Amsterdam_RP-D-2017-2216,Amsterdam_RP-D-2017-2230,Amsterdam_RP-D-1980-59-32,Amsterdam_RP-D-1980-59-2,Amsterdam_RP-D-1980-59-70,Amsterdam_RP-D-2017-2217,Amsterdam_RP-D-1980-59-50,Amsterdam_RP-D-1980-59-77,Amsterdam_RP-D-1980-59-53,Amsterdam_RP-D-1980-59-5,Amsterdam_RP-D-1980-59-31,Amsterdam_RP-D-1980-59-75,Amsterdam_RP-D-1980-59-49,Amsterdam_RP-D-1980-59-64,Amsterdam_RP-D-1980-59-3,Amsterdam_RP-D-1980-59-84,Amsterdam_RP-D-1980-59-56,Amsterdam_RP-D-1980-59-85,Amsterdam_RP-D-1980-59-72,Amsterdam_RP-D-1980-59-79,Amsterdam_RP-D-2017-2222,Amsterdam_RP-D-1980-59-44,Amsterdam_RP-D-1980-59-83,Amsterdam_RP-D-1980-59-54,Amsterdam_RP-D-1980-59-16,Amsterdam_RP-D-1980-59-13,Amsterdam_RP-D-1980-59-58,Amsterdam_RP-D-1980-59-78,Amsterdam_RP-D-1980-59-61,Amsterdam_RP-D-1980-59-82,Amsterdam_RP-D-1980-59-42,Amsterdam_RP-D-1980-59-69,Amsterdam_RP-D-1980-59-65,Amsterdam_RP-D-1980-59-15,Amsterdam_RP-D-1980-59-39,Amsterdam_RP-D-2017-2238,Amsterdam_RP-D-1980-59-57,Amsterdam_RP-D-1980-59-80,Amsterdam_RP-D-2017-2243,Amsterdam_RP-D-1980-59-48,Amsterdam_RP-D-1980-59-7,Amsterdam_RP-D-1980-59-40,Amsterdam_RP-D-1980-59-55,Amsterdam_RP-D-1980-59-67,Amsterdam_RP-D-1980-59-63,Amsterdam_RP-D-2017-2226,Amsterdam_RP-D-1980-59-51,Amsterdam_RP-D-1980-59-18,Amsterdam_RP-D-1980-59-76,Amsterdam_RP-D-1982-43-IMEL-136,Amsterdam_RP-D-1982-43-HIMELSCHEIN-22,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-11,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-47,Amsterdam_RP-D-1982-43-IMEL-163,Amsterdam_RP-D-1982-43-HIMELSCHEIN-18,Amsterdam_RP-D-1982-43-HIMELSCHEIN-21,Amsterdam_RP-D-1982-43-IMEL-138,Amsterdam_RP-D-1982-43-IMEL-154,Amsterdam_RP-D-1982-43-IMEL-135,Amsterdam_RP-D-1982-43-IMEL-157,Amsterdam_RP-D-1982-43-IMEL-161,Amsterdam_RP-D-1982-43-HIMELSCHEIN-1,Amsterdam_RP-D-1982-43-IMEL-160,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-37,Amsterdam_RP-D-1982-43-IMEL-164,Amsterdam_RP-D-1982-43-IMEL-153,Amsterdam_RP-D-1982-43-HIMELSCHEIN-29A,Amsterdam_RP-D-1982-43-IMEL-126,Amsterdam_RP-D-1982-43-HIMELSCHEIN-24,Amsterdam_RP-D-1982-43-HIMELSCHEIN-51,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-58,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-46,Amsterdam_RP-D-1982-43-HIMELSCHEIN-29C,Amsterdam_RP-D-1982-43-IMEL-145,Amsterdam_RP-D-1982-43-HIMELSCHEIN-19,Amsterdam_RP-D-1982-43-IMEL-142,Amsterdam_RP-D-1982-43-HIMELSCHEIN-23,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-2,Amsterdam_RP-D-1982-43-HIMELSCHEIN-29B,Amsterdam_RP-D-1982-43-HIMELSCHEIN-25,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-66,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-44,Amsterdam_RP-D-1982-43-IMEL-133,Amsterdam_RP-D-1982-43-IMEL-140,Amsterdam_RP-D-1982-43-IMEL-155,Amsterdam_RP-D-1982-43-IMEL-2,Amsterdam_RP-D-1982-43-IMEL-132,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-8,Amsterdam_RP-D-1982-43-HOUCHART-6,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-57,Amsterdam_RP-D-1982-43-IMEL-148,Amsterdam_RP-D-1982-43-IMEL-152,Amsterdam_RP-D-1982-43-HIMELSCHEIN-2,Amsterdam_RP-D-1982-43-HIMELSCHEIN-5,Amsterdam_RP-D-1982-43-MESDAG(H.W.)-48,Amsterdam_RP-D-1982-43-MAUVE(ANTON)-8,Amsterdam_RP-D-1982-43-MAUVE(ANTON)-5,Amsterdam_RP-D-1982-43-HIMELSCHEIN-31,Amsterdam_RP-D-1982-43-VANHOUTEN(B.E.)-12,Amsterdam_RP-D-1982-43-IMEL-21,Amsterdam_RP-D-1982-43-MASSON(CH.)-7,Amsterdam_RP-D-1982-43-KOSTER(E.B.)-4,Amsterdam_RP-D-1982-43-DEKOO(J.)-16,Amsterdam_RP-D-1982-43-MASSON(CH.)-8,Amsterdam_RP-D-1982-43-MAUVE(ANTON)-9,Amsterdam_RP-D-1982-43-HIMELSCHEIN-41,Amsterdam_RP-D-1982-43-M.BAUER-2,Amsterdam_RP-D-1982-43-F.BRACQUEMOND-1,Amsterdam_RP-D-1982-43-F.BRACQUEMOND-2,Amsterdam_RP-D-1982-43-J.TENBRINK-4,Amsterdam_RP-D-1982-43-M.BAUER-121,Amsterdam_RP-D-1982-43-A.BREDIUS-49,Amsterdam_RP-D-1982-43-F.KHNOPFF-1,Amsterdam_RP-D-1982-43-A.BREDIUS-70,Amsterdam_RP-D-1982-43-A.BREDIUS-64,Amsterdam_RP-D-1982-43-J.TENBRINK-3,Amsterdam_RP-D-1982-43-F.BUHOT-6,Amsterdam_RP-D-1982-43-M.BAUER-112,Amsterdam_RP-D-1982-43-A.BREDIUS-46,Amsterdam_RP-D-1982-43-M.BAUER-119,Amsterdam_RP-D-1982-43-M.BAUER-32,Amsterdam_RP-D-1982-43-A.BREDIUS-65,Amsterdam_RP-D-1982-43-A.BREDIUS-61,Amsterdam_RP-D-1982-43-M.BAUER-51,Amsterdam_RP-D-1982-43-A.BREDIUS-73,Amsterdam_RP-D-1982-43-M.BAUER-53,Amsterdam_RP-D-1982-43-J.H.DE.BOIS-1,Amsterdam_RP-D-1982-43-A.BREDIUS-48,Amsterdam_RP-D-1982-43-M.BAUER-33,Amsterdam_RP-D-1982-43-M.BAUER-63,Amsterdam_RP-D-1982-43-A.BREDIUS-44,Amsterdam_RP-D-1982-43-CH.BUHOT-3,Amsterdam_RP-D-1982-43-A.BREDIUS-75,Amsterdam_RP-D-1982-43-M.BAUER-31,Amsterdam_RP-D-1982-43-CH.BUHOT-DOC.1,Amsterdam_RP-D-1982-43-A.BREDIUS-57,Amsterdam_RP-D-1982-43-F.BUHOT-5,Amsterdam_RP-D-1982-43-M.BAUER-59,Amsterdam_RP-D-1982-43-A.BREDIUS-54,Amsterdam_RP-D-1982-43-A.BREDIUS-43,Amsterdam_RP-D-1982-43-M.BAUER-52,Amsterdam_RP-D-1982-43-A.BREDIUS-60,Amsterdam_RP-D-1982-43-A.BREDIUS-53,Amsterdam_RP-D-1982-43-A.BREDIUS-74,Amsterdam_RP-D-1982-43-M.BAUER-45,Amsterdam_RP-D-1982-43-M.BAUER-117,Amsterdam_RP-D-1982-43-A.BRIDGE-1,Amsterdam_RP-D-1982-43-M.BAUER-122,Amsterdam_RP-D-1982-43-A.BREDIUS-62,Amsterdam_RP-D-1982-43-M.BAUER-84,Amsterdam_RP-D-1982-43-J.TENBRINK-1,Amsterdam_RP-D-1982-43-J.H.DE.BOIS-3,Amsterdam_RP-D-1984-40-P.MOLTZER-4,Amsterdam_RP-D-1984-40-P.MOLTZER-1,Amsterdam_RP-D-M.MARIS-31,Amsterdam_RP-D-W.MARIS-16,Amsterdam_RP-D-M.MARIS-21,Amsterdam_RP-D-W.MARIS-24,Amsterdam_RP-D-W.MARIS-12,Amsterdam_RP-D-W.MARIS-14,Amsterdam_RP-D-W.MARIS-11,Amsterdam_RP-D-M.MARIS-33,Amsterdam_RP-D-M.MARIS-23,Amsterdam_RP-D-2017-2490,Amsterdam_RP-D-W.MARIS-30,Amsterdam_RP-D-2017-2489,Amsterdam_RP-D-M.MARIS-32,Amsterdam_RP-D-W.MARIS-17,Amsterdam_RP-D-M.MARIS-34,Amsterdam_RP-D-W.MARIS-21,Amsterdam_RP-D-M.MARIS-25,Amsterdam_RP-D-2017-2491,Amsterdam_RP-D-M.MARIS-26,Amsterdam_RP-D-W.MARIS-13,Amsterdam_RP-D-2017-2547,Amsterdam_RP-D-2017-2513,Amsterdam_RP-D-2017-2584,Amsterdam_RP-D-2017-2566,Amsterdam_RP-D-2017-2550,Amsterdam_RP-D-2017-2526,Amsterdam_RP-D-1984-40-J.P.VETH-289,Amsterdam_RP-D-1984-40-J.P.VETH-279,Amsterdam_RP-D-1984-40-J.MESSCHAERT-9,Amsterdam_RP-D-1984-40-A.MAUVE-4,Amsterdam_RP-D-1984-40-J.P.VETH-284,Amsterdam_RP-D-1984-40-J.P.VETH-281,Amsterdam_RP-D-1984-40-J.P.VETH-296,Amsterdam_RP-D-1984-40-J.MESSCHAERT-8,Amsterdam_RP-D-1984-40-J.P.VETH-276,Amsterdam_RP-D-1984-40-POSTHUMUSMEYJES-6,Amsterdam_RP-D-1984-40-J.P.VETH-286,Amsterdam_RP-D-1982-43-MAZE-SENCIER-1,Amsterdam_RP-D-1982-43-DESAVORNINLOHMAN-1,Amsterdam_RP-D-1982-43-DESAVORNINLOHMAN-10,Amsterdam_RP-D-1982-43-DESAINT-JACQUES-1,Amsterdam_RP-D-1982-43-K.S.-4,Amsterdam_RP-D-1982-43-DESAINT-JACQUES-2,Amsterdam_RP-D-1982-43-MAUS(OCT.)-24,Amsterdam_RP-D-1982-43-MAUS(OCT.)-10,Amsterdam_RP-D-1982-43-IMEL-42,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-38,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-12,Amsterdam_RP-D-1982-43-IMEL-43,Amsterdam_RP-D-1982-43-IMEL-89,Amsterdam_RP-D-1982-43-MAUS(OCT.-12,Amsterdam_RP-D-1982-43-IMEL-57,Amsterdam_RP-D-1982-43-IMEL-37,Amsterdam_RP-D-1982-43-IMEL-74,Amsterdam_RP-D-1982-43-MAUS(OCTAVE)-15,Amsterdam_RP-T-2015-41-521,Amsterdam_RP-D-1982-43-MAUS(OCT.)-32,Amsterdam_RP-D-1982-43-IMEL-80,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-31,Amsterdam_RP-D-1982-43-IMEL-53,Amsterdam_RP-D-1982-43-IMEL-79,Amsterdam_RP-D-1982-43-IMEL-69,Amsterdam_RP-D-1982-43-MAUS(OCT.)-22,Amsterdam_RP-D-1982-43-IMEL-56,Amsterdam_RP-D-1982-43-IMEL-94,Amsterdam_RP-D-1982-43-IMEL-39,Amsterdam_RP-D-1982-43-IMEL-125,Amsterdam_RP-D-1982-43-MAUS(OCT.)-13,Amsterdam_RP-D-1982-43-IMEL-122,Amsterdam_RP-D-1982-43-IMEL-120,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-13,Amsterdam_RP-D-1982-43-MAUS(OCT.)-42,Amsterdam_RP-D-1982-43-MAUS(OCT.)-25,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-19A,Amsterdam_RP-D-1982-43-MAUS(OCT.)-40,Amsterdam_RP-D-1982-43-IMEL-71,Amsterdam_RP-D-1982-43-IMEL-55,Amsterdam_RP-D-1982-43-MAUS(O.)-48,Amsterdam_RP-D-1982-43-IMEL-33,Amsterdam_RP-D-1982-43-MAUS(OCTAVE)-7,Amsterdam_RP-D-1982-43-IMEL-96,Amsterdam_RP-D-1982-43-IMEL-59,Amsterdam_RP-D-1982-43-HOUCHART-1,Amsterdam_RP-D-1982-43-IMEL-45,Amsterdam_RP-D-1982-43-IMEL-67,Amsterdam_RP-D-1982-43-MARZOE(R.)-1,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-26,Amsterdam_RP-D-1982-43-IMEL-70,Amsterdam_RP-D-1982-43-MAUS(OCT.)-23,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-8,Amsterdam_RP-D-1982-43-IMEL-118,Amsterdam_RP-D-1982-43-IMEL-88,Amsterdam_RP-D-1982-43-IMEL-60,Amsterdam_RP-D-1982-43-VANHOUTEN(B.)-10,Amsterdam_RP-D-1982-43-IMEL-76,Amsterdam_RP-D-1982-43-MAUS(OCTAVE)-6,Amsterdam_RP-D-1982-43-MAUS(OCT.)-14,Amsterdam_RP-D-1982-43-MAUS(OCT.)-36,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-2,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-7,Amsterdam_RP-D-1982-43-MAUS(OCTAVE)-26,Amsterdam_RP-D-1982-43-MAUS(OCT.)-54,Amsterdam_RP-D-1982-43-IMEL-93,Amsterdam_RP-D-1982-43-MAUS(OCT.)-37,Amsterdam_RP-D-1982-43-IMEL-103,Amsterdam_RP-D-2017-2404,Amsterdam_RP-D-2017-2445,Amsterdam_RP-D-1907-88,Amsterdam_RP-D-2017-2377,Amsterdam_RP-D-2017-2415,Amsterdam_RP-D-2017-2447,Amsterdam_RP-D-2017-2437,Amsterdam_BI-1950-17-96,Amsterdam_RP-D-2017-2403,Amsterdam_RP-D-2017-2449,Amsterdam_BI-1950-17-94,Amsterdam_RP-D-2017-2380,Amsterdam_RP-D-2017-2378,Amsterdam_RP-D-2017-2432,Amsterdam_RP-D-2017-2391,Amsterdam_BI-1950-17-162,Amsterdam_RP-D-2017-2417,Amsterdam_RP-D-2017-2414,Amsterdam_RP-D-2017-2406,Amsterdam_RP-D-2017-2425,Amsterdam_RP-D-1982-43-FELIX-FENEON-11,Amsterdam_RP-D-1982-43-FELIX-FENEON-15A,Amsterdam_RP-D-1982-43-HIJNER(A.)-9,Amsterdam_RP-D-1982-43-FELIX-FENEON-6,Amsterdam_RP-D-1982-43-KEITH(W.C.)-2,Amsterdam_RP-D-1982-43-FONTAINAS(A.)-2,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-2B,Amsterdam_RP-D-1982-43-HIJNER(A.)-6,Amsterdam_RP-D-1982-43-FRANDSEN(D.)-11,Amsterdam_RP-D-1982-43-FELIX-FENEON-16,Amsterdam_RP-D-1982-43-KLINKENBERG(K.)-1,Amsterdam_RP-D-1982-43-FRANDSEN(D.)-8,Amsterdam_RP-D-1982-43-FONTAINAS(A.)-4,Amsterdam_RP-D-1982-43-FRAIPONT(G.)-1,Amsterdam_RP-D-1982-43-KEITH(W.C)-3,Amsterdam_RP-D-1982-43-FELIX-FENEON-4,Amsterdam_RP-D-1982-43-HOYNCKV.P.(J.)-11,Amsterdam_RP-D-1982-43-HIJNER(A.)-3,Amsterdam_RP-D-1982-43-FONTAINAS(A.)-3,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-4A,Amsterdam_RP-D-1982-43-FRANTZ(H.)-1,Amsterdam_RP-D-1982-43-KEMPEES(JO)-1,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-19,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-14B,Amsterdam_RP-D-1982-43-FRAIPONT(G.)-2,Amsterdam_RP-D-1982-43-CASTLEKEITH(W.)-1,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-14A,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-5B,Amsterdam_RP-D-1982-43-FRANDSEN(D.)-6,Amsterdam_RP-D-1982-43-ERLICH(J.)-29,Amsterdam_RP-D-1982-43-HURET(JULES)-1,Amsterdam_RP-D-2017-1729,Amsterdam_RP-D-2017-1756,Amsterdam_RP-D-2017-1861,Amsterdam_RP-D-1982-43-ERLICH(J.)-21,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-14A,Amsterdam_RP-D-1982-43-HADKINSON(E.)-20B,Amsterdam_RP-D-2017-1880,Amsterdam_RP-D-2017-1744,Amsterdam_RP-D-2017-1699,Amsterdam_RP-D-1982-43-ENSOR(JAMES)-2,Amsterdam_RP-D-2017-1856,Amsterdam_RP-D-2017-1700,Amsterdam_RP-D-1982-43-HUYSMANS(J.K.)-6,Amsterdam_RP-D-1982-43-GUERARD(H.)-2,Amsterdam_RP-D-1982-43-ERENS(F.)-1,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-3,Amsterdam_RP-D-1982-43-ERLICH(J.)-26,Amsterdam_RP-D-1982-43-ERLICH(J.)-20,Amsterdam_RP-D-2017-1722,Amsterdam_RP-D-2017-1676,Amsterdam_RP-D-1982-43-EASTMAN-1,Amsterdam_RP-D-2017-1921,Amsterdam_RP-D-2017-1719,Amsterdam_RP-D-2017-1803,Amsterdam_RP-D-2017-1890,Amsterdam_RP-D-1982-43-ERLICH(J.)-8A,Amsterdam_RP-D-1982-43-HADKINSON(E.)-20A,Amsterdam_RP-D-1982-43-GROUX(H.DE)-1,Amsterdam_RP-D-2017-1798,Amsterdam_RP-D-1982-43-ERLICH(J.)-23,Amsterdam_RP-D-1982-43-KLOOS(W.)-58B,Amsterdam_RP-D-2017-1863,Amsterdam_RP-D-2017-1808,Amsterdam_RP-D-2017-1752,Amsterdam_RP-D-1982-43-ERLICH(J.)-13,Amsterdam_RP-D-1982-43-ERLICH(J.)-11,Amsterdam_RP-D-2017-1681,Amsterdam_RP-D-1982-43-ERLICH(J.)-27,Amsterdam_RP-D-1982-43-EEKHOUD(G.)-14,Amsterdam_RP-D-1982-43-HADKINSON(E.)-10B,Amsterdam_RP-D-1982-43-GUERARD(H.)-1,Amsterdam_RP-D-1982-43-ERLICH(J.)-17,Amsterdam_RP-D-2017-1882,Amsterdam_RP-D-1982-43-ERLICH(JEANNE)-5,Amsterdam_RP-D-1982-43-HADKINSON(E.)-13,Amsterdam_RP-D-2017-1879,Amsterdam_RP-D-1982-43-EEDEN(F.VAN)-19,Amsterdam_RP-D-1982-43-EPHRUSSI(CH.)-1,Amsterdam_RP-D-2017-1685,Amsterdam_RP-D-2017-1753,Amsterdam_RP-D-1982-43-EEKHOUD(G.)-3,Amsterdam_RP-D-1982-43-P.ALFANA-2,Amsterdam_RP-D-1982-43-J.COMTE-13,Amsterdam_RP-D-1982-43-J.DESTREE-14,Amsterdam_RP-D-1982-43-GIESE(J.)-8,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-75,Amsterdam_RP-D-1982-43-CLAPIER-H.-8,Amsterdam_RP-D-1982-43-J.DESTREE-5,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-78A,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-62,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-60,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-74,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-94,Amsterdam_RP-D-1982-43-CLAPIER-H.-6,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-80,Amsterdam_RP-D-1982-43-GIESE(J.)-7,Amsterdam_RP-D-1982-43-J.COMTE-7,Amsterdam_RP-D-1984-40-J.KNOEF-2,Amsterdam_RP-D-1982-43-J.DESTREE-2,Amsterdam_RP-D-1982-43-J.COMTE-1,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-67,Amsterdam_RP-D-1982-43-CLAPIER-H.-23,Amsterdam_RP-D-1982-43-CLAPIER-H.-22,Amsterdam_RP-D-1982-43-ISRAELS(H.L.)-1A,Amsterdam_RP-D-1982-43-GODOY(A.)-1,Amsterdam_RP-D-1982-43-GIESE(J.)-9,Amsterdam_RP-D-1982-43-ISINGJR.(A.)-3,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-54,Amsterdam_RP-D-1982-43-J.COMTE-14,Amsterdam_RP-D-1982-43-P.ALFANA-1,Amsterdam_RP-D-1982-43-J.DESTREE-11,Amsterdam_RP-D-1982-43-GIESE(J.)-11,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-102,Amsterdam_RP-D-1982-43-J.DESTREE-3,Amsterdam_RP-D-1982-43-J.DESTREE-12,Amsterdam_RP-D-1982-43-GEUNS(C.VAN)-3,Amsterdam_RP-D-1982-43-J.DESTREE-15,Amsterdam_RP-D-1982-43-CLAPIER-H.-19,Amsterdam_RP-D-1982-43-GIESE(J.)-3,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-57,Amsterdam_RP-D-1982-43-J.COMTE-10,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-96,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-91,Amsterdam_RP-D-1982-43-J.COMTE-5,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-81,Amsterdam_RP-D-1982-43-J.COMTE-3,Amsterdam_RP-D-1982-43-GEUNS(C.VAN)-1,Amsterdam_RP-D-1982-43-COURBOIN-3,Amsterdam_RP-D-1982-43-GIGOUX-1,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-55,Amsterdam_RP-D-1982-43-J.COMTE-8,Amsterdam_RP-D-1982-43-J.DESTREE-1,Amsterdam_RP-D-1982-43-GEROME-2,Amsterdam_RP-D-1982-43-GIESE(J.)-1,Amsterdam_RP-D-1982-43-HERMANS(C.)-1,Amsterdam_RP-D-1982-43-JACOBSON(JOHNJ.)-2,Amsterdam_RP-D-1982-43-HARTNIBBRIG(F.)-2,Amsterdam_RP-D-1982-43-A.DELZANT-9,Amsterdam_RP-D-1982-43-KRABBE(H.M.)-5,Amsterdam_RP-D-1982-43-HOLBACH(A.)-2,Amsterdam_RP-D-1982-43-A.DELZANT-27,Amsterdam_RP-D-1982-43-HERPAIN(J.)-1,Amsterdam_RP-D-1982-43-HENNER(H.)-1,Amsterdam_RP-D-1982-43-A.DELZANT-15,Amsterdam_RP-D-1982-43-KOPPENOL(C.)-3,Amsterdam_RP-D-1982-43-HENKES(G.)-3,Amsterdam_RP-D-1982-43-A.DELZANT-4,Amsterdam_RP-D-1982-43-A.DELZANT-22,Amsterdam_RP-D-1982-43-HAVERMAN(H.J.)-25,Amsterdam_RP-D-1982-43-HENRICUS-3,Amsterdam_RP-D-1982-43-A.DELZANT-26,Amsterdam_RP-D-1982-43-HOLLMAN(J.)-3,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-7,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-6,Amsterdam_RP-D-1982-43-IMEL-75,Amsterdam_RP-D-1982-43-HIMELSCHEIN-49,Amsterdam_RP-D-1982-43-MAUS(O.)-41,Amsterdam_RP-D-1982-43-IMEL-36,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-19,Amsterdam_RP-D-1982-43-MAUS(OCTAVE)-9,Amsterdam_RP-D-1982-43-MAUS(OCT.)-55,Amsterdam_RP-D-1982-43-IMEL-108,Amsterdam_RP-D-1982-43-MAUS(OCT.)-11,Amsterdam_RP-D-1982-43-MAUS(OCT.)-38,Amsterdam_RP-D-1982-43-IMEL-99,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-30,Amsterdam_RP-D-1982-43-IMEL-78,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-25,Amsterdam_RP-D-1982-43-MAUS(OCT.)-21,Amsterdam_RP-D-1982-43-IMEL-38,Amsterdam_RP-D-1982-43-IMEL-47,Amsterdam_RP-D-1982-43-MAUS(OCT.)-33,Amsterdam_RP-D-1982-43-IMEL-66,Amsterdam_RP-D-R.N.ROLANDHOLST-70,Amsterdam_RP-D-1980-59-108,Amsterdam_RP-D-1980-59-118,Amsterdam_RP-D-R.N.ROLANDHOLST-86,Amsterdam_RP-D-1980-59-88,Amsterdam_RP-D-1980-59-96,Amsterdam_RP-D-1980-59-95,Amsterdam_RP-D-R.N.ROLANDHOLST-101,Amsterdam_RP-D-1980-59-89,Amsterdam_RP-D-BAKHUYSEN.L.-19,Amsterdam_RP-D-1980-59-97,Amsterdam_RP-D-1980-59-106,Amsterdam_RP-D-1980-59-98,Amsterdam_RP-D-1980-59-113,Amsterdam_RP-D-R.N.ROLANDHOLST-98,Amsterdam_RP-D-1980-59-111,Amsterdam_RP-D-1980-59-91,Amsterdam_RP-D-1980-59-93,Amsterdam_RP-D-R.N.ROLANDHOLST-75,Amsterdam_RP-D-R.N.ROLANDHOLST-71,Amsterdam_RP-D-1980-59-102,Amsterdam_RP-D-1980-59-90,Amsterdam_RP-D-R.N.ROLANDHOLST-79,Amsterdam_RP-D-1980-59-110,Amsterdam_RP-D-R.N.ROLANDHOLST-67,Amsterdam_RP-D-1980-59-100,Amsterdam_RP-D-1980-59-94,Amsterdam_RP-D-1979-2B,Amsterdam_RP-D-R.N.ROLANDHOLST-96,Amsterdam_RP-D-1980-59-105,Amsterdam_RP-D-2017-2248,Amsterdam_RP-D-1980-59-112,Amsterdam_RP-D-R.N.ROLANDHOLST-97,Amsterdam_RP-D-1980-59-99,Amsterdam_RP-D-R.N.ROLANDHOLST-68,Amsterdam_RP-D-R.N.ROLANDHOLST-95,Amsterdam_RP-D-1980-59-104,Amsterdam_RP-D-1980-59-117,Amsterdam_RP-D-1980-59-87,Amsterdam_RP-D-R.N.ROLANDHOLST-92,Amsterdam_RP-D-1980-59-109,Amsterdam_RP-D-1980-59-107,Amsterdam_RP-D-1979-2A,Amsterdam_RP-D-1980-59-103,Amsterdam_RP-D-1980-59-101,Amsterdam_RP-D-1980-59-86,Amsterdam_RP-D-1982-43-PELADAN(J.)-1,Amsterdam_RP-D-1982-43-MORICE(CH.)-2,Amsterdam_RP-D-1982-43-MOUREY(G.)-14,Amsterdam_RP-D-1982-43-PERNOT(M.)-4,Amsterdam_RP-D-1982-43-PETERS(C.H.)-1,Amsterdam_RP-D-1982-43-PAILLARD(H.)-7,Amsterdam_RP-D-1982-43-MOUREY(G.)-22,Amsterdam_RP-D-1982-43-PENNELL(J.)-5,Amsterdam_RP-D-1982-43-PASCHAL(L.)-9B,Amsterdam_RP-D-1982-43-PENNELL(J.)-2,Amsterdam_RP-D-1982-43-PERK(BETSY)-6,Amsterdam_RP-D-1982-43-MISTRAL(F.)-8,Amsterdam_RP-D-2017-2529,Amsterdam_RP-D-2017-2549,Amsterdam_RP-D-2017-2515,Amsterdam_RP-D-2017-2521,Amsterdam_RP-D-2017-2559,Amsterdam_RP-D-2017-2512,Amsterdam_RP-D-1977-2-5,Amsterdam_RP-D-1977-2-4,Amsterdam_RP-D-2017-2586,Amsterdam_RP-D-2017-2517,Amsterdam_RP-D-1977-2-3,Amsterdam_RP-D-2017-2569,Amsterdam_RP-D-2017-2514,Amsterdam_RP-D-2017-2534,Amsterdam_RP-D-1977-2-6,Amsterdam_RP-D-2017-2523,Amsterdam_RP-D-2017-2520,Amsterdam_RP-D-1977-2-1,Amsterdam_RP-D-2017-2554,Amsterdam_RP-D-2017-2527,Amsterdam_RP-D-2017-2544,Amsterdam_RP-D-2017-2570,Amsterdam_RP-D-2017-2524,Amsterdam_RP-D-1977-2-7,Amsterdam_RP-D-2017-2548,Amsterdam_RP-D-1977-2-2,Amsterdam_RP-D-2017-2511,Amsterdam_RP-D-2017-2509,Amsterdam_RP-D-2017-2555,Amsterdam_RP-D-1981-5,Amsterdam_RP-D-1980-4,Amsterdam_RP-D-1980-59-1,Amsterdam_RP-D-1982-43-DEVRIES(RWP)-2,Amsterdam_RP-D-1982-43-PICA-113,Amsterdam_RP-D-1982-43-DEVRIES(H)-1,Amsterdam_RP-D-1982-43-DEVRIES(H.)-6,Amsterdam_RP-D-1982-43-DEWAARDT-6,Amsterdam_RP-D-1982-43-DEVRIES(RWP)-4,Amsterdam_RP-D-1982-43-DEWAARDT-9,Amsterdam_RP-D-1982-43-DEWAARDT-1,Amsterdam_RP-D-1982-43-DEWAARDT-2,Amsterdam_RP-D-1982-43-DEVRIES(H.)-9,Amsterdam_RP-D-1982-43-DEWAARDT-3,Amsterdam_RP-D-1982-43-DEVRIES(H)-2,Amsterdam_RP-D-1982-43-DEVRIES(RWP)-6,Amsterdam_RP-D-1982-43-DEVRIES(HUGO)-1,Amsterdam_RP-D-1982-43-DEWAARDT-4,Amsterdam_RP-D-1982-43-DEVRIES(RWP)-3,Amsterdam_RP-D-1984-40-A.VERWEY-51,Amsterdam_RP-D-1982-43-9,Amsterdam_RP-D-1982-43-25,Amsterdam_RP-T-2004-103-24(V),Amsterdam_RP-D-1982-43-HENKES(G.)-6,Amsterdam_RP-D-1982-43-KOSTER(A.L.)-29A,Amsterdam_RP-D-1982-43-A.DELZANT-18,Amsterdam_RP-D-1982-43-KOSTER(A.L.)-25A,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-6,Amsterdam_RP-D-2017-2340,Amsterdam_RP-D-BAKHUIZENII.L-6,Amsterdam_RP-D-1982-43-A.DELZANT-6,Amsterdam_RP-D-2017-2312,Amsterdam_RP-D-2017-2329,Amsterdam_RP-D-BAKHUIZENII.L-8,Amsterdam_RP-D-2017-2338,Amsterdam_RP-D-1982-43-HOLBACH(A.)-7,Amsterdam_BI-1950-17-8,Amsterdam_RP-D-1982-43-A.DELZANT-13,Amsterdam_RP-D-1982-43-A.DELZANT-2,Amsterdam_RP-D-1982-43-DEJONG(J.)-1,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-9B,Amsterdam_RP-D-1982-43-A.DELZANT-23,Amsterdam_RP-D-1982-43-A.DELZANT-7,Amsterdam_RP-D-1982-43-HENDRIX(H.)-1,Amsterdam_RP-D-1982-43-DEJONG(J.)-5,Amsterdam_RP-D-1982-43-HOLBACH(A.)-5,Amsterdam_RP-D-1982-43-KOSTER(A.L.)-34,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-12,Amsterdam_RP-D-1982-43-HOLBACH(A.)-11,Amsterdam_RP-D-1982-43-A.DELZANT-8,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-3,Amsterdam_RP-D-1982-43-HAVERMAN(H.J.)-1,Amsterdam_RP-D-1982-43-KONING(A.H.)-4,Amsterdam_RP-D-1982-43-A.DELZANT-3,Amsterdam_RP-D-1982-43-HOLMES(HELENM.)-2,Amsterdam_RP-D-1982-43-A.DELZANT-14,Amsterdam_RP-D-1982-43-A.DELZANT-28,Amsterdam_RP-D-1982-43-A.DELZANT-11,Amsterdam_RP-D-1982-43-HENRICUS-2,Amsterdam_RP-D-1982-43-A.DELZANT-19,Amsterdam_RP-D-1982-43-KONING(A.H.)-3,Amsterdam_RP-D-1982-43-HENRICUS-5,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-5,Amsterdam_RP-D-1982-43-HOLLMAN(J.)-2,Amsterdam_RP-D-1982-43-VANHOUTEN(B.)-9,Amsterdam_RP-D-1982-43-VANHOUTEN(B.)-5,Amsterdam_RP-D-1982-43-VANHOUTEN(B.)-29,Amsterdam_RP-D-1982-43-DEKOO(J.)-9,Amsterdam_RP-D-1982-43-KNOBEL(F.M.)-1,Amsterdam_RP-D-1982-43-DEKOO(J.)-31,Amsterdam_RP-D-1982-43-MAUVE(ANTON)-11,Amsterdam_RP-D-1982-43-DEMEESTER(J.)-3,Amsterdam_RP-D-1982-43-MASSON(CH.)-10,Amsterdam_RP-D-1982-43-MASSON(CH.)-2,Amsterdam_RP-D-1982-43-KOSTER(E.B.)-5,Amsterdam_RP-D-1982-43-HIMELSCHEIN-39A,Amsterdam_RP-D-1982-43-DEKOO(J.)-22,Amsterdam_RP-D-1982-43-DEKOO(J.)-33,Amsterdam_RP-D-1982-43-KOWALSKI-1,Amsterdam_RP-D-1982-43-MAUVE(ANTON)-10,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-84,Amsterdam_RP-D-1982-43-DEMEESTER(J.)-4A,Amsterdam_RP-D-1982-43-HIMELSCHEIN-6,Amsterdam_RP-D-1982-43-KRUSEMAN(TH.)-1,Amsterdam_RP-D-1982-43-DEKOO(J.)-37,Amsterdam_RP-D-1982-43-DEKOO(J.)-23,Amsterdam_RP-D-1982-43-HIMELSCHEIN-43,Amsterdam_RP-D-1982-43-DEMEESTER(J.)-4,Amsterdam_RP-D-1982-43-VANHOUTEN(B.E.)-17,Amsterdam_RP-D-1982-43-IMEL-25,Amsterdam_RP-D-1982-43-IMEL-10,Amsterdam_RP-D-1982-43-MASSON(CH.)-6,Amsterdam_RP-D-1982-43-HIMELSCHEIN-45,Amsterdam_RP-D-1982-43-HIMELSCHEIN-46,Amsterdam_RP-D-1982-43-KOSTER(E.B.)-1,Amsterdam_RP-D-1982-43-DEMEESTER(J.)-5,Amsterdam_RP-D-1982-43-IMEL-27B,Amsterdam_RP-D-1982-43-DEMEESTER(J.)-2,Amsterdam_RP-D-1982-43-MASSON(CH.)-1,Amsterdam_RP-D-1982-43-IMEL-16,Amsterdam_RP-D-1982-43-HIMELSCHEIN-39B,Amsterdam_RP-D-1982-43-IMEL-9B,Amsterdam_RP-D-1982-43-HIMELSCHEIN-37,Amsterdam_RP-D-1982-43-VANHOUTEN(B.)-11,Amsterdam_RP-D-1982-43-MASSON(CH.)-5,Amsterdam_RP-D-1982-43-IMEL-22,Amsterdam_RP-D-1982-43-HIMELSCHEIN-42,Amsterdam_RP-D-1982-43-MASSON(CH.)-9,Amsterdam_RP-D-1982-43-IMEL-20,Amsterdam_RP-D-1982-43-KOSTER(E.B.)-3,Amsterdam_RP-D-1982-43-VANHOUTEN(B.E.)-15,Amsterdam_RP-D-1982-43-IMEL-13,Amsterdam_RP-D-1982-43-DEKOO(J.)-36,Amsterdam_RP-D-1982-43-MASSON(CH.)-3,Amsterdam_RP-D-1982-43-DEKOO(J.)-38,Amsterdam_RP-D-1982-43-FRANDSEN(D.)-1,Amsterdam_RP-D-1982-43-HIJNER(A.)-1,Amsterdam_RP-D-1982-43-KAHN(G.)-2B,Amsterdam_RP-D-1982-43-FELIX-FENEON-15B,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-15,Amsterdam_RP-D-1982-43-KEITH(W.C)-4,Amsterdam_RP-D-1982-43-DURAND-GREVILLE-2A,Amsterdam_RP-D-1982-43-FIERENS(L.)-1,Amsterdam_RP-D-1982-43-FRAYA-3C,Amsterdam_RP-D-1982-43-FANTIN-LATOUR-1,Amsterdam_RP-D-1982-43-FRANDSEN(D.)-14A,Amsterdam_RP-D-1982-43-KLOOS(W.)-58A,Amsterdam_RP-D-2017-1484,Amsterdam_RP-D-2017-1538,Amsterdam_RP-D-2017-1412,Amsterdam_RP-D-2017-1568,Amsterdam_RP-D-2017-1348,Amsterdam_RP-D-MOUILLERON.A-4,Amsterdam_RP-D-2017-1634,Amsterdam_RP-D-2017-1368,Amsterdam_RP-D-2017-1417,Amsterdam_RP-D-2017-1562,Amsterdam_RP-D-MOUILLERON.A-35,Amsterdam_RP-D-2017-1466,Amsterdam_RP-D-MOUILLERON.A-21,Amsterdam_RP-D-2017-1548,Amsterdam_RP-D-2017-1501,Amsterdam_RP-D-MOUILLERON.A.-10,Amsterdam_RP-D-2017-1629,Amsterdam_RP-D-MOUILLERON.A-23,Amsterdam_RP-D-2017-1587,Amsterdam_RP-D-2017-1425,Amsterdam_RP-D-2017-1605,Amsterdam_RP-D-2017-1596,Amsterdam_RP-D-1981-20,Amsterdam_RP-D-2017-1544,Amsterdam_RP-D-2017-1647,Amsterdam_RP-D-2017-1403,Amsterdam_RP-D-2017-1603,Amsterdam_RP-D-2017-1585,Amsterdam_RP-D-2017-1618,Amsterdam_RP-D-2017-1602,Amsterdam_RP-D-2017-1416,Amsterdam_RP-D-2017-1615,Amsterdam_RP-D-2017-1639,Amsterdam_RP-D-2017-1408,Amsterdam_RP-D-2017-1385,Amsterdam_RP-D-2017-1546,Amsterdam_RP-D-2017-1457,Amsterdam_RP-D-2017-1462,Amsterdam_RP-D-2017-1552,Amsterdam_RP-D-2017-1622,Amsterdam_RP-D-2017-1349,Amsterdam_RP-D-2017-1434,Amsterdam_RP-D-MOUILLERON.A-41,Amsterdam_RP-D-2017-1555,Amsterdam_RP-D-2017-1413,Amsterdam_RP-D-2017-1464,Amsterdam_RP-D-DR.SCHAEPMAN-8,Amsterdam_RP-D-MOUILLERON.A-22,Amsterdam_RP-D-2017-1475,Amsterdam_RP-D-MOUILLERON.A-31,Amsterdam_RP-D-2017-1480,Amsterdam_RP-D-2017-1369,Amsterdam_RP-D-2017-1419,Amsterdam_RP-D-2017-1588,Amsterdam_RP-D-2017-1514,Amsterdam_RP-D-2017-1616,Amsterdam_RP-D-2017-1642,Amsterdam_RP-D-2017-1352,Amsterdam_RP-D-MOUILLERON.A-48,Amsterdam_RP-D-2017-1527,Amsterdam_RP-D-DR.SCHAEPMAN-4,Amsterdam_RP-D-2017-1354,Amsterdam_RP-D-1982-43-A.BAERTSOEN-31,Amsterdam_RP-D-1982-43-BAC-17,Amsterdam_RP-T-1954-1,Amsterdam_RP-D-1982-43-DRAAYER(A.)-4,Amsterdam_RP-D-1982-43-A.BAERTSOEN-4,Amsterdam_RP-D-1982-43-A.BAERTSOEN-29,Amsterdam_RP-D-1982-43-DHAYRMOND-4,Amsterdam_RP-D-1982-43-A.BAERTSOEN-23,Amsterdam_RP-D-1982-43-A.BAERTSOEN-30,Amsterdam_RP-D-1982-43-A.BAERTSOEN-1,Amsterdam_RP-D-1982-43-A.BAERTSOEN-6,Amsterdam_RP-D-1982-43-A.BAERTSOEN-27,Amsterdam_RP-D-1982-43-A.BAERTSOEN-24,Amsterdam_RP-D-1982-43-E.DINET-5,Amsterdam_RP-D-1982-43-M.BATILLIAT-1,Amsterdam_RP-D-1982-43-DHAYRMOND-2,Amsterdam_RP-D-1982-43-P.DEVOLUY-5,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-18,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-2,Amsterdam_RP-D-1982-43-GAUTIER(TH.)-1,Amsterdam_RP-D-1982-43-GEORG(ST.)-1,Amsterdam_RP-D-1982-43-GEUL(J.)-5,Amsterdam_RP-D-1982-43-P.DEVOLUY-13,Amsterdam_RP-D-1982-43-P.DEVOLUY-3,Amsterdam_RP-D-1982-43-GEUL(J.)-2,Amsterdam_RP-D-1982-43-KLEYKAMP(C.G.)-1B,Amsterdam_RP-D-1982-43-KLEYKAMP(C.G.)-1A,Amsterdam_RP-D-1982-43-C.DESTREE-10,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-28,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-25,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-10,Amsterdam_RP-D-1982-43-P.DEVOLUY-9,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-13,Amsterdam_RP-D-1982-43-C.DESTREE-3,Amsterdam_RP-D-1982-43-P.DEVOLUY-11,Amsterdam_RP-D-1982-43-FUJIKAWA(J.)-2,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-29,Amsterdam_RP-D-1982-43-C.DESTREE-5,Amsterdam_RP-D-1982-43-P.DEVOLUY-10,Amsterdam_RP-D-1982-43-KARSEN(ED.)-69,Amsterdam_RP-D-1982-43-FUJIKAWA(J.)-3,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-11,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-3,Amsterdam_RP-D-1982-43-GEFFROY(G.)-1,Amsterdam_RP-D-1982-43-P.DEVOLUY-4,Amsterdam_RP-D-1982-43-P.DEVOLUY-2,Amsterdam_RP-D-1982-43-GASKIN(ARTHUR.J.)-3,Amsterdam_RP-D-1982-43-C.DESTREE-9,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-23,Amsterdam_RP-D-1982-43-HOLLMAN(J.)-1,Amsterdam_RP-D-2017-2296,Amsterdam_RP-D-2017-2342,Amsterdam_RP-D-2017-2316,Amsterdam_BI-1950-17-35,Amsterdam_RP-D-1982-43-A.DELZANT-25,Amsterdam_RP-D-1982-43-HINLOPEN(C.)-1,Amsterdam_BI-1950-17-59,Amsterdam_BI-1950-17-51,Amsterdam_BI-1950-17-58,Amsterdam_BI-1950-17-28,Amsterdam_RP-D-1982-43-HENRICUS-9,Amsterdam_RP-D-1982-43-HENRICUS-6,Amsterdam_RP-D-1982-43-A.DELZANT-17,Amsterdam_RP-D-1982-43-HOLMES(HELENM.)-1,Amsterdam_RP-D-1984-40-J.P.VETH-299,Amsterdam_RP-D-1982-43-HENNY(CARL)-1,Amsterdam_RP-D-1982-43-HOLBACH(A.)-12,Amsterdam_RP-D-1982-43-HERSCHEL(A.)-2,Amsterdam_RP-D-1982-43-A.DELZANT-21,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-1,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-9A,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-10,Amsterdam_RP-D-1982-43-HITCHCOCK(C.)-1,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-1,Amsterdam_RP-D-1982-43-HENLEY(W.E.)-4,Amsterdam_RP-D-1982-43-HENRICUS-8,Amsterdam_RP-D-1982-43-KOSTER(A.L.)-29B,Amsterdam_RP-D-1982-43-A.DELZANT-16,Amsterdam_RP-D-1982-43-HARTNIBBRIG(F.)-1,Amsterdam_RP-D-1982-43-HAVERMAN(H.J.)-11,Amsterdam_RP-D-1982-43-HARTNIBBRIG(F.)-3,Amsterdam_RP-D-1982-43-HAVERMAN(H.J.)-22,Amsterdam_RP-D-1982-43-LHOPITAL(C.)-7,Amsterdam_RP-D-1982-43-HENKES(G.)-2,Amsterdam_RP-D-1982-43-JACOBSON(JOHNJ.)-1,Amsterdam_RP-D-1982-43-HOLLMAN(J.)-4,Amsterdam_RP-D-1982-43-HOLBACH(A.)-9,Amsterdam_RP-D-1982-43-HENRICUS-1,Amsterdam_RP-D-1982-43-HEYTING(A.)-1,Amsterdam_RP-D-1982-43-A.DELZANT-20,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-103,Amsterdam_RP-D-1982-43-ISRAELS(H.L.)-1B,Amsterdam_RP-D-1982-43-J.COMTE-4,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-83,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-65,Amsterdam_RP-D-1982-43-GEROME-1,Amsterdam_RP-D-1982-43-ISRAELS(JOZEF)-77,Amsterdam_RP-D-1982-43-J.COMTE-2,Amsterdam_RP-D-1982-43-ISRAELS(ISAAC)-79,Amsterdam_RP-D-1982-43-P.ALFANA-3,Amsterdam_RP-D-1982-43-P.ALFANA-4,Amsterdam_RP-D-1982-43-J.COMTE-15,Amsterdam_RP-D-1977-2-10,Amsterdam_RP-D-1982-43-4,Amsterdam_RP-D-2017-2452-425,Amsterdam_RP-D-2017-2452-396,Amsterdam_RP-D-1984-40-W.SLUITER-1,Amsterdam_RP-D-1982-43-19,Amsterdam_RP-D-2017-2452-423,Amsterdam_RP-D-2017-2452-427,Amsterdam_RP-D-1982-43-15,Amsterdam_RP-D-1982-43-17,Amsterdam_RP-D-1982-43-26,Amsterdam_RP-D-1982-43-IMEL-48,Amsterdam_RP-D-1982-43-IMEL-85,Amsterdam_RP-D-1982-43-MAUS(OCT.)-35,Amsterdam_RP-D-1982-43-MAUS(OCTAVE)-1,Amsterdam_RP-D-1982-43-IMEL-68,Amsterdam_RP-D-1982-43-IMEL-91,Amsterdam_RP-D-1982-43-IMEL-77,Amsterdam_RP-D-1982-43-MAUS(OCT.)-8,Amsterdam_RP-D-1982-43-IMEL-50B,Amsterdam_RP-D-1982-43-IMEL-109,Amsterdam_RP-D-1982-43-IMEL-84,Amsterdam_RP-D-1982-43-IMEL-62,Amsterdam_RP-D-1982-43-IMEL-46,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-35,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-4,Amsterdam_RP-D-1982-43-IMEL-112,Amsterdam_RP-D-1982-43-MARTENS(W.J.)-1,Amsterdam_RP-D-1982-43-MARIS(W.)-3A,Amsterdam_RP-D-1982-43-IMEL-63,Amsterdam_RP-D-1982-43-IMEL-35,Amsterdam_RP-D-1982-43-IMEL-83,Amsterdam_RP-D-1982-43-IMEL-95,Amsterdam_RP-D-1982-43-MAUS(OCTAVE)-47,Amsterdam_RP-D-1982-43-IMEL-58,Amsterdam_RP-D-1982-43-IMEL-90,Amsterdam_RP-D-1982-43-MARIUS(G.H.)-6,Amsterdam_RP-D-1982-43-IMEL-98,Amsterdam_RP-D-1982-43-IMEL-92,Amsterdam_RP-D-1982-43-IMEL-61,Amsterdam_RP-D-1982-43-DEBAS-3,Amsterdam_RP-D-1984-40-A.WARBURG-1,Amsterdam_RP-D-1982-43-81,Amsterdam_RP-D-1982-43-60,Amsterdam_RP-D-1982-43-J.M.BEATTY-1,Amsterdam_RP-D-1982-43-KEPPEL-1,Amsterdam_RP-D-1982-43-BOELS-DEBUCK-28,Amsterdam_RP-D-1982-43-GEUNS-6,Amsterdam_RP-D-1982-43-PERK(BETSY)-2,Amsterdam_RP-D-1982-43-PERK(BETSY)-5,Amsterdam_RP-D-1982-43-MOES(WALLY)-174,Amsterdam_RP-D-1982-43-PERK(BETSY)-1,Amsterdam_RP-D-1982-43-PASCHAL(LEON)-6,Amsterdam_RP-D-1982-43-PAILLARD(H.)-5,Amsterdam_RP-D-1982-43-PENNELL(J.)-9,Amsterdam_RP-D-1982-43-MOES(WALLY)-178,Amsterdam_RP-D-1982-43-PAILLARD(H.)-10,Amsterdam_RP-D-1982-43-PAILLARD(H.)-6,Amsterdam_RP-D-1982-43-MOUREY(G.)-21,Amsterdam_RP-D-1982-43-PAILLARD(H.)-4,Amsterdam_RP-D-1982-43-MOES(WALLY)-181,Amsterdam_RP-D-1982-43-PENNELL(J.)-7,Amsterdam_RP-D-1982-43-PERK(BETSY)-4,Amsterdam_RP-D-1982-43-PASCHAL(LEON)-14,Amsterdam_RP-D-1982-43-PENNELL(J.)-6,Amsterdam_RP-D-1982-43-PENNELL(J.)-10,Amsterdam_RP-D-1982-43-PASCHAL(L.)-18,Amsterdam_RP-D-1982-43-DEMIOMANDRE(F.)-18,Amsterdam_RP-D-1982-43-DEMONT(P.)-12,Amsterdam_RP-D-1982-43-PAILLARD(H.)-2,Amsterdam_RP-D-1982-43-PERK(B.)-3,Amsterdam_RP-D-2017-2452-450,Amsterdam_RP-D-1982-43-DESOLPRAY-5,Amsterdam_RP-D-1982-43-DESOLPRAY-7,Amsterdam_RP-D-1982-43-DESOLPRAY-4,Amsterdam_RP-D-1982-43-SOLVAY(L.)-1,Amsterdam_RP-D-1982-43-PICA(V.)-14,Amsterdam_RP-D-1982-43-DESOLPRAY-6,Amsterdam_RP-D-1982-43-DESOLPRAY-3,Amsterdam_RP-D-1982-43-DEZWART-36,Amsterdam_RP-D-1982-43-DEVRIESLAM-1,Amsterdam_RP-T-BR-2017-1-6-26(V),Amsterdam_RP-D-1982-43-A.PIT-124,Amsterdam_RP-D-1982-43-A.PIT-15,Amsterdam_RP-D-1982-43-A.PIT-1,Amsterdam_RP-D-1982-43-A.PIT-21,Amsterdam_RP-D-1982-43-A.BREDIUS-52,Amsterdam_RP-D-1982-43-M.BAUER-82,Amsterdam_RP-D-1982-43-A.BREDIUS-69,Amsterdam_RP-D-1982-43-F.BUHOT-3,Amsterdam_RP-D-1982-43-A.BREDIUS-66,Amsterdam_RP-D-1982-43-A.BREDIUS-68,Amsterdam_RP-D-1982-43-M.BAUER-64,Amsterdam_RP-D-1982-43-M.BAUER-74,Amsterdam_RP-D-1982-43-M.BAUER-46,Amsterdam_RP-D-1982-43-M.BAUER-71,Amsterdam_RP-D-1982-43-A.BREDIUS-58,Amsterdam_RP-D-1982-43-M.BAUER-120,Amsterdam_RP-D-1982-43-PENNELL(J.)-4,Amsterdam_RP-D-1982-43-MOUREY(G.)-11,Amsterdam_RP-D-1981-7,Amsterdam_RP-D-1982-43-M.BAUER-6,Amsterdam_RP-D-1982-43-M.BAUER-26,Amsterdam_RP-D-1982-43-MOES(WALLY)-182,Amsterdam_RP-D-1982-43-PENNELL(J.)-1,Amsterdam_RP-D-1982-43-PASCHAL(L.)-8,Amsterdam_RP-D-1982-43-PASCHAL(L.)-9A,Amsterdam_RP-D-1982-43-PENNELL(J.)-8,Amsterdam_RP-D-1982-43-PAILLARD(H.)-9,Amsterdam_RP-D-1982-43-MOES(WALLY)-183,Amsterdam_RP-D-1982-43-83,Amsterdam_RP-D-1982-43-GEUNS-5,Amsterdam_RP-D-1984-40-KITTYV.VLOTEN-1,Amsterdam_RP-D-1982-43-16,Amsterdam_RP-D-1982-43-24,Amsterdam_RP-D-1982-43-7,Amsterdam_RP-D-1982-43-F.BRACQUEMOND-4,Amsterdam_BI-1950-17-74,Amsterdam_BI-1950-17-71,Amsterdam_RP-D-2017-2326,Amsterdam_BI-1950-17-2,Amsterdam_RP-D-2017-2333,Amsterdam_BI-1950-17-75,Amsterdam_RP-D-BAKHUIZENII.L-9,Amsterdam_BI-1950-17-80,Amsterdam_RP-D-R.N.ROLANDHOLST-114,Amsterdam_RP-D-R.N.ROLANDHOLST-113,Amsterdam_RP-D-2017-2336,Amsterdam_BI-1950-17-52,Amsterdam_BI-1950-17-11,Amsterdam_BI-1950-17-70,Amsterdam_BI-1950-17-40,Amsterdam_BI-1950-17-12,Amsterdam_RP-D-1982-43-L.BENEDITE-39,Amsterdam_RP-D-1982-43-L.BENEDITE-40,Amsterdam_RP-D-1982-43-DESLANDES-25,Amsterdam_RP-D-1982-43-DESLANDES-31,Amsterdam_RP-D-1982-43-L.BENEDITE-47,Amsterdam_RP-D-1982-43-E.BEETZ-1,Amsterdam_RP-D-1982-43-L.BENEDITE-42,Amsterdam_RP-D-1982-43-H.BERALDI-7,Amsterdam_RP-D-1982-43-H.L.BERCKENHOFF-4,Amsterdam_RP-D-1982-43-L.BENEDITE-6,Amsterdam_RP-D-1982-43-L.BENEDITE-29,Amsterdam_RP-D-1982-43-DESLANDES-29B,Amsterdam_RP-D-1982-43-L.BENEDITE-33,Amsterdam_RP-D-1982-43-L.BENEDITE-45,Amsterdam_RP-D-1982-43-HANNON(TH.)-1,Amsterdam_RP-D-1982-43-HAMERTON(P.G.)-1,Amsterdam_RP-D-1982-43-H.BERALDI-8,Amsterdam_RP-D-1982-43-L.BENEDITE-35,Amsterdam_RP-D-1982-43-DIEPENBROCK-19,Amsterdam_RP-D-1982-43-L.BENEDITE-3,Amsterdam_RP-D-1982-43-L.BENEDITE-1,Amsterdam_RP-D-1982-43-DESLANDES-26A,Amsterdam_RP-D-1982-43-A.BOUVENNE-5,Amsterdam_RP-D-1982-43-A.BAERTSOEN-32,Amsterdam_RP-D-1982-43-DESLANDES-22B,Amsterdam_RP-D-1982-43-HAGA-HAIG(E.B.DE)-1,Amsterdam_RP-D-1982-43-HADKINSON(E.)-3A,Amsterdam_RP-D-1982-43-A.BAERTSOEN-28,Amsterdam_RP-D-1982-43-E.DINET-7,Amsterdam_RP-D-1982-43-DOORMAN(J.)-1,Amsterdam_RP-D-1982-43-P.DEVOLUY-1,Amsterdam_RP-D-1982-43-DOORMAN(J.)-2,Amsterdam_RP-D-1982-43-A.BAERTSOEN-26,Amsterdam_RP-D-1982-43-CHAMPNEY-1,Amsterdam_RP-D-2017-2350,Amsterdam_BI-1950-17-41,Amsterdam_RP-D-R.N.ROLANDHOLST-108,Amsterdam_BI-1950-17-10,Amsterdam_BI-1950-17-82,Amsterdam_RP-D-R.N.ROLANDHOLST-110,Amsterdam_RP-D-BACKHUYSEN.G.-3,Amsterdam_BI-1950-17-69,Amsterdam_BI-1950-17-14,Amsterdam_BI-1950-17-61,Amsterdam_BI-1950-17-66,Amsterdam_RP-D-R.N.ROLANDHOLST-103,Amsterdam_RP-D-2017-2322,Amsterdam_BI-1950-17-42,Amsterdam_BI-1950-17-36,Amsterdam_BI-1950-17-78,Amsterdam_BI-1950-17-32,Amsterdam_BI-1950-17-7,Amsterdam_BI-1950-17-62,Amsterdam_BI-1950-17-57,Amsterdam_BI-1950-17-37,Amsterdam_BI-1950-17-64,Amsterdam_RP-D-1982-43-GEFFROY(G.)-2,Amsterdam_RP-D-1982-43-KARSEN(ED.)-33,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-12,Amsterdam_RP-D-1982-43-KLOOS(W.)-1,Amsterdam_RP-D-1982-43-KARSEN(ED.)-34,Amsterdam_RP-D-1982-43-KHNOPFF(F.)-22,Amsterdam_RP-D-1982-43-P.DEVOLUY-8,Amsterdam_RP-D-1982-43-GEUL(J.)-6,Amsterdam_RP-D-MOUILLERON.A-11,Amsterdam_RP-D-2017-1607,Amsterdam_RP-D-MOUILLERON.A-8,Amsterdam_RP-D-MOUILLERON.A-30,Amsterdam_RP-D-2017-1386,Amsterdam_RP-D-2017-1569,Amsterdam_RP-D-2017-1492,Amsterdam_RP-D-MOUILLERON.A-15,Amsterdam_RP-D-2017-1370,Amsterdam_RP-D-MOUILLERON.A-46,Amsterdam_RP-D-DR.SCHAEPMAN-10,Amsterdam_RP-D-MOUILLERON.A.-1,Amsterdam_RP-D-2017-1414,Amsterdam_RP-D-MOUILLERON.A-33,Amsterdam_RP-D-2017-1379,Amsterdam_RP-D-2017-1402,Amsterdam_RP-D-DR.SCHAEPMAN-5,Amsterdam_RP-D-2017-1377,Amsterdam_RP-D-DR.SCHAEPMAN-20,Amsterdam_RP-D-2017-1374,Amsterdam_RP-D-MOUILLERON.A-24,Amsterdam_RP-D-2017-1620,Amsterdam_RP-D-1982-43-J.H.DEBUSSY-1,Amsterdam_RP-D-1982-43-F.BUHOT-7,Amsterdam_RP-D-1982-43-H.BUHOT-8,Amsterdam_RP-D-1982-43-N.CABANE-1,Amsterdam_RP-D-1982-43-F.BUHOT-15,Amsterdam_RP-D-1982-43-BOELS(J)-5,Amsterdam_RP-D-1982-43-H.BUHOT-1,Amsterdam_RP-D-1982-43-C.BUYSSE-5,Amsterdam_RP-D-1982-43-E.BOASSON-8,Amsterdam_RP-D-1982-43-F.BUHOT-11,Amsterdam_RP-D-1982-43-BOELS(J)-3,Amsterdam_RP-D-1982-43-C.BUYSSE-1,Amsterdam_RP-D-1982-43-F.BUHOT-12,Amsterdam_RP-D-1982-43-H.BUHOT-4,Amsterdam_RP-D-1982-43-H.BUHOT-13,Amsterdam_RP-D-1982-43-C.BUYSSE-2,Amsterdam_RP-D-1982-43-E.BOASSON-1,Amsterdam_RP-D-1982-43-H.BUHOT-12,Amsterdam_RP-D-1982-43-PH.BURTY-1,Amsterdam_RP-D-1982-43-F.BUHOT-18,Amsterdam_RP-D-1982-43-BOELS(J)-4,Amsterdam_RP-D-1982-43-F.BUHOT-17,Amsterdam_RP-D-1982-43-CAPPELLE-1,Amsterdam_RP-D-1982-43-H.BUHOT-14,Amsterdam_RP-D-1982-43-H.BUHOT-7,Amsterdam_RP-D-1982-43-BOELS(J)-6,Amsterdam_RP-D-1982-43-F.BOGGS-1,Amsterdam_RP-D-1982-43-F.BUHOT-10,Amsterdam_RP-D-1982-43-E.BOASSON-10,Amsterdam_RP-D-1982-43-H.BUHOT-6,Amsterdam_RP-D-1982-43-CASSATT-1,Amsterdam_RP-D-1982-43-F.BUHOT-14,Amsterdam_RP-D-1982-43-H.BUHOT-2,Amsterdam_RP-D-1982-43-F.BUHOT-13,Amsterdam_RP-D-1982-43-DEZWART-45,Amsterdam_RP-D-1982-43-DEZWART-37,Amsterdam_RP-D-1982-43-DEVRIES(C.J.)-1,Amsterdam_RP-D-1982-43-DEZWART-42,Amsterdam_RP-D-1982-43-DEZWART-44,Amsterdam_RP-D-1982-43-DEZWART-40,Amsterdam_RP-D-1982-43-DOSS.VERLAINE-42,Amsterdam_RP-D-1982-43-A.PIT-61,Amsterdam_RP-D-1982-43-DEZWART-38,Amsterdam_RP-D-1982-43-DEZWART-43A,Amsterdam_RP-T-BR-2017-1-6-26(R),Amsterdam_RP-D-1982-43-MELCHERS(F.M.)-32,Amsterdam_RP-D-2020-17,Amsterdam_BI-H-2153,Amsterdam_RP-D-1982-43-A.PIT-125,Amsterdam_RP-D-1982-43-A.PIT-22,Amsterdam_RP-D-1982-43-A.PIT-11,Amsterdam_RP-D-1982-43-A.PIT-14,Amsterdam_RP-D-1982-43-A.PIT-12,Amsterdam_RP-D-1982-43-A.PIT-4,Amsterdam_RP-D-1982-43-A.PIT-3,Amsterdam_RP-D-1982-43-A.PIT-6,Amsterdam_RP-D-1982-43-A.PIT-17,Amsterdam_RP-D-1982-43-A.PIT-10,Amsterdam_RP-D-1982-43-A.PIT-18,Amsterdam_RP-D-1982-43-A.PIT-9,Amsterdam_RP-D-1982-43-A.PIT-5,Amsterdam_RP-D-1982-43-A.PIT-2,Amsterdam_RP-D-1982-43-A.PIT-16,Amsterdam_RP-D-1982-43-A.PIT-19,Amsterdam_RP-P-1975-94,Amsterdam_RP-P-1980-357,Amsterdam_RP-P-1912-2327,Amsterdam_RP-P-1950-155D,Amsterdam_RP-P-1912-2325,Amsterdam_NG-NM-12786-F,Amsterdam_NG-NM-12786-C,Amsterdam_NG-NM-12786-E,Amsterdam_AK-MAK-937,Amsterdam_NG-NM-9662,Amsterdam_RP-T-1938-141A,Amsterdam_RP-T-1940-127,Amsterdam_RP-T-1888-A-1874,Amsterdam_RP-P-1884-A-8165,Amsterdam_RP-T-1888-A-1875'

# %%
b = breif.split(sep=',')

# %%
s = s[~s['Art_ID'].isin(b)]

# %%
s.to_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv')

# %%
s['Artist'].value_counts().head(30)
# Out:
# anonymous                     17255
# Jan Luyken                     4053
# George Hendrik Breitner        3928
# Reinier Vinkeles (I)           2387
# Isaac Israels                  1956
# Brewster & Co.                 1560
# Marius Bauer                   1511
# Johannes Tavenraat             1509
# Simon Fokke                    1265
# Rembrandt van Rijn             1219
# Willem Witsen                  1208
# Jacob Houbraken                 977
# Jacques Callot                  969
# Antonio Tempesta                966
# Anton Mauve                     887
# Allen & Ginter                  860
# Caspar Luyken                   854
# Giovanni Battista Piranesi      836
# Philips Galle                   825
# Romeyn de Hooghe                823
# Cornelis Vreedenburgh           819
# Carel Adolph Lion Cachet        764
# Albrecht Dürer                  757
# Johann Sadeler (I)              756
# Bernard Picart                  749
# Jozef Israëls                   738
# ...

# %% [markdown]
# ### openrefine 정제를 위한 추가 작업

# %% [markdown]
# 1. Material 정렬

# %%
superset_main = pd.read_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv', index_col='Unnamed: 0')

print(superset_main.shape)
superset_main.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (323068, 14)
#    Column  ...                          Gdrive_ID
# 0       0  ...  1WD8TD-QteV0hN3Aq8T8aHknX_Pbe_9Ia
# 1       1  ...  1W4wlRRYxknlwbjPImoY-1aw5y7tXlKgQ
#
# [2 rows x 14 columns]

# %%
superset_main.index = range(len(superset_main))

# %%
superset_main['Material(clean)'] = superset_main['Material'].str.replace('[', '')\
                  .str.replace(']', '').str.replace('\'', '').str.replace(' ', '')

# %%
superset_main['Material(clean)'] = superset_main['Material(clean)'].map(lambda x : sorted(x.split(',')) if pd.notnull(x) else pd.np.nan)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """Entry point for launching an IPython kernel.

# %%
superset_main['Material'].unique()
# Out:
# array(["['brush', 'chalk', 'paper']", "['paper', 'pencil']",
#        "['brush', 'ink', 'paper', 'pen']", ...,
#        "['Drawings', 'blackchalk', 'withbrushandgrayandbrownwashonbluepaper;verso:blackchalk']",
#        "['Blue-coloredwoodblockprint(aizuri-e);inkandcoloronpaper;fanprint(uchiwa-e)onhorizontalaibansheet\\\\\\\\\\\\\\\\n\\\\\\\\\\\\\\\\n', 'Prints']",
#        "['Oakandlindenwood', 'Woodwork', 'carvedandpainted']"],
#       dtype=object)

# %%
superset_main = superset_main[['Column', 'Art_ID', 'Title', 'Artist', 'Date', 'Period', 'Style',
       'Worktype', 'Material(clean)', 'Measurement', 'License', 'Filename',
       'Filesize', 'Gdrive_ID']]

# %%
superset_main.columns = ['Column', 'Art_ID', 'Title', 'Artist', 'Date', 'Period', 'Style',
       'Worktype', 'Material', 'Measurement', 'License', 'Filename',
       'Filesize', 'Gdrive_ID']

# %%
superset_main.to_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv')

# %% [markdown]
# 2. kaggle period 추가

# %%
kaggle_period = pd.read_csv('/content/drive/MyDrive/ArtDive/Art/metadata/Kaggle/kaggle_dataset_period-csv.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
kaggle_period.head(30)
# Out:
#     Index  ...                        period
# 0       0  ...                    Modern Art
# 1       1  ...                    Modern Art
# 2       2  ...                           NaN
# 3       3  ...                           NaN
# 4       4  ...                           NaN
# 5       5  ...                  Japanese Art
# 6       6  ...                    Modern Art
# 7       7  ...                  Japanese Art
# 8       8  ...                    Modern Art
# 9       9  ...  Western Post Renaissance Art
# 10     10  ...                  Japanese Art
# 11     11  ...                    Modern Art
# 12     12  ...       Western Renaissance Art
# 13     13  ...                  Japanese Art
# 14     14  ...  Western Post Renaissance Art
# 15     15  ...                    Modern Art
# 16     16  ...                  Japanese Art
# 17     17  ...                  Japanese Art
# 18     18  ...       Western Renaissance Art
# 19     19  ...                  Japanese Art
# ...

# %%
superset_main['Period'].notnull().sum()
# Out:
# 1621

# %%
for idx in range(len(kaggle_period)):
  artid = kaggle_period.loc[idx, 'Art_ID']
  period = kaggle_period.loc[idx, 'period']
  superset_main.loc[superset_main['Art_ID'] == artid, 'Period'] = period

# %%
superset_main['Period'].notnull().sum()
# Out:
# 104404

# %%
superset_main[superset_main['Art_ID'].str.contains('Kaggle')].tail(30)
# Out:
#         Column        Art_ID  ...  Filesize                          Gdrive_ID
# 289173  291545  Kaggle_99690  ...   45005.0  1o8Nzt5xEOsj29jVjtu4kaeRgJRcH_sAz
# 289174  291546  Kaggle_84485  ...  143583.0  1oY7V4Fsi2AjQnHrYpYyiL9VcKAsh-PrL
# 289175  291547  Kaggle_31567  ...   57490.0  1N_fjRgnKvo5y7N1Pp5GcJA1T3MOGvllC
# 289176  291548  Kaggle_10995  ...   41251.0  1LGtH-mJ9HXGyYzVh4lNIpC5c2NCoU2S3
# 289177  291549  Kaggle_93386  ...   25703.0  1T8JuGBcjbFk6LppK7e7a8fxWUwy0EVUM
# 289178  291550  Kaggle_76082  ...   42097.0  1eiiXrmcS9RdWGmSrfxWIynLNgCauMfiv
# 289179  291551  Kaggle_58747  ...   26284.0  1ULdkQLfCvU7qO4fgY6KE0Zy8MYSO31_Y
# 289180  291552  Kaggle_45104  ...   34313.0  1OTdwk3s4Own1NK-rbvDYlOnve_hE1nhm
# 289181  291553  Kaggle_43177  ...  206247.0  1lRvYs5HMFTO_C3P1u7pv956rQpP_99vT
# 289182  291554  Kaggle_86325  ...   46845.0  1MEZqw7P-mekZk9AdDlDZxRt_mDeQZ9_I
# 289183  291555  Kaggle_85070  ...   43574.0  1zkls1IVdE8PIv4v3Zth68C8l4c-1F2rG
# ...

# %% [markdown]
# 3.License 값 채우기

# %%
from ast import literal_eval

# %%
tmp = pd.read_csv('/content/drive/MyDrive/ArtDive/Art/metadata/Amsterdam/amsterdam_meatdata_backup.csv', converters={"identifier": literal_eval})

# %%
tmp['artid']=tmp['identifier'].map(lambda x: 'Amsterdam_'+x[-1])

# %%
tmp.columns
# Out:
# Index(['Unnamed: 0', 'Art_ID', 'Title', 'Artist', 'Date', 'Period', 'Style',
#        'Worktype', 'Material', 'Measurement', 'License', 'Filename',
#        'Filesize', 'Gdrive_ID'],
#       dtype='object')

# %%
tmp['rights'].value_counts()
# Out:
# http://creativecommons.org/publicdomain/mark/1.0/    491744
# http://creativecommons.org/licenses/by-nc-nd/4.0/     67136
# Name: rights, dtype: int64

# %%
tmp['identifier'][0]
# Out:
# "['http://hdl.handle.net/10934/RM0001.COLLECT.47758', 'RP-P-OB-21.370A']"

# %%
tmp.head()
# Out:
#    Unnamed: 0  ...                        artid
# 0           0  ...    Amsterdam_RP-P-OB-21.370A
# 1           1  ...  Amsterdam_RP-P-OB-21.460(V)
# 2           2  ...     Amsterdam_RP-P-OB-21.578
# 3           3  ...  Amsterdam_RP-P-1903-A-23275
# 4           4  ...     Amsterdam_RP-P-OB-21.863
#
# [5 rows x 14 columns]

# %%
art1 = tmp.loc[tmp['rights'].str.contains('1.0'),'artid']
art4 = tmp.loc[tmp['rights'].str.contains('4.0'),'artid']

# %%
art1 = art1.values
art4 = art4.values

# %%
'Amsterdam_RP-P-OB-21.370A' in art1[:5]
# Out:
# True

# %%
len(art4)
# Out:
# 67136

# %%
check_ams_lic = superset_main.loc[superset_main['Art_ID'].str.contains('Ams'), 'Art_ID'].values

# %%
i=0
for artid in check_ams_lic:
  print(i)
  i += 1
  if artid in art1 :
    superset_main.loc[superset_main['Art_ID']==artid, 'License'] = 2
  elif artid in art4 :
    superset_main.loc[superset_main['Art_ID']==artid, 'License'] = 3
  else :
    superset_main.loc[superset_main['Art_ID']==artid, 'License'] = 5
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 170307
# 170308
# 170309
# 170310
# 170311
# 170312
# 170313
# 170314
# 170315
# 170316
# 170317
# 170318
# 170319
# 170320
# 170321
# 170322
# 170323
# 170324
# 170325
# 170326
# 170327
# 170328
# 170329
# 170330
# 170331
# 170332
# 170333
# 170334
# 170335
# 170336
# 170337
# 170338
# 170339
# 170340
# 170341
# 170342
# 170343
# 170344
# 170345
# 170346
# 170347
# 170348
# 170349
# 170350
# 170351
# 170352
# 170353
# 170354
# 170355
# 170356
# 170357
# 170358
# 170359
# 170360
# 170361
# 170362
# 170363
# 170364
# 170365
# 170366
# 170367
# 170368
# 170369
# 170370
# 170371
# 170372
# 170373
# 170374
# 170375
# 170376
# 170377
# 170378
# 170379
# 170380
# 170381
# 170382
# 170383
# 170384
# 170385
# 170386
# 170387
# 170388
# 170389
# 170390
# 170391
# 170392
# 170393
# 170394
# 170395
# 170396
# 170397
# 170398
# 170399
# 170400
# 170401
# 170402
# 170403
# 170404
# 170405
# 170406
# 170407
# 170408
# 170409
# 170410
# 170411
# 170412
# ...

# %%
superset_main['License'].isnull().sum()
# Out:
# 0

# %%
superset_main.head(2)
# Out:
#    Column                    Art_ID  ...                          Gdrive_ID SiHeung
# 0       0    Amsterdam_RP-T-1985-11  ...  1WD8TD-QteV0hN3Aq8T8aHknX_Pbe_9Ia       0
# 1       1  Amsterdam_RP-T-1924-36-6  ...  1W4wlRRYxknlwbjPImoY-1aw5y7tXlKgQ       0
#
# [2 rows x 15 columns]

# %%
superset_main.to_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv')

# %%
art1[:3]
# Out:
# array(['Amsterdam_RP-P-OB-21.370A', 'Amsterdam_RP-P-OB-21.460(V)',
#        'Amsterdam_RP-P-OB-21.578'], dtype=object)

# %%
'Amsterdam_RP-T-1985-11' in art1
# Out:
# False

# %%
superset_main.loc[superset_main['Art_ID'].str.contains('Ams') & superset_main['License'] == 1, 'License'] = 2

# %%
superset_main.loc[superset_main['Art_ID'].str.contains('Ams'), 'License'].value_counts()
# Out:
# 2.0    156807
# 5.0     18138
# 3.0       362
# Name: License, dtype: int64

# %%
superset_main[superset_main['License'].isnull()]
# Out:
#        Column  ... SiHeung
# 0           0  ...       0
# 1           1  ...       0
# 2           2  ...       0
# 3           3  ...       0
# 4           4  ...       0
# ...       ...  ...     ...
# 18425   18425  ...       0
# 18426   18426  ...       0
# 18427   18427  ...       0
# 18428   18428  ...       0
# 18429   18429  ...       0
#
# [18138 rows x 15 columns]

# %%
tmp.shape
# Out:
# (34056, 56)

# %%
tmp['License'].value_counts()
# Out:
# 6.0    33972
# 5.0       84
# Name: License, dtype: int64

# %%
superset_main = pd.read_csv('/content/drive/MyDrive/ArtDive/Art/metadata/raw_superset_main.csv', index_col='Unnamed: 0')

print(superset_main.shape)
superset_main.head(2)
# Out:
# (323068, 14)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Column  ...                          Gdrive_ID
# 0       0  ...  1WD8TD-QteV0hN3Aq8T8aHknX_Pbe_9Ia
# 1       1  ...  1W4wlRRYxknlwbjPImoY-1aw5y7tXlKgQ
#
# [2 rows x 14 columns]

# %%
superset_main['License'].value_counts()
# Out:
# 1.0    113895
# 6.0     33781
# 5.0        84
# 3.0         1
# Name: License, dtype: int64

# %%
superset_main.loc[superset_main['Art_ID'].str.contains('Kaggle'), 'License'] = 1

# %%
superset_main.loc[superset_main['Art_ID']=='Kaggle_64100', 'License'] = 3

# %%
superset_main['License'].value_counts()
# Out:
# 1.0    113895
# 6.0     33781
# 5.0        84
# 3.0         1
# Name: License, dtype: int64

# %% [markdown]
# 5. SiHeung 칼럼 생성

# %%
superset_main['SiHeung'] = 0

# %%
import pandas as pd
from ast import literal_eval

# %%
pd.options.display.max_rows = 500

# %%
path = './dataset/check_kaggle_piece/'

# %%
checked = pd.read_csv(path + '../check_kaggle(작업중).csv')

# %%
checked = checked.sort_values('Title')[:147]

print(checked.shape)
checked.head()
# Out:
# (147, 9)
#       Column        Art_ID                         Title            Artist  \
# 794     4364  Kaggle_36356   A Devil in Woman's Likeness  Aubrey Beardsley
# 822     4559  Kaggle_34749   A Devil in Woman's Likeness  Aubrey Beardsley
# 1319    7913  Kaggle_99814              A Modern Olympia      Paul Cezanne
# 906     5119  Kaggle_54631               A Pair of Shoes  Vincent van Gogh
# 1008    5885  Kaggle_48833  A Regatta on the Grand Canal         Canaletto
#
#                                               Wiki_Link  Style  Genre  Media  \
# 794   https://www.wikiart.org/en/aubrey-beardsley/a-...    NaN    NaN    NaN
# 822   https://www.wikiart.org/en/aubrey-beardsley/a-...    NaN    NaN    NaN
# 1319  https://www.wikiart.org/en/paul-cezanne/a-mode...    NaN    NaN    NaN
# 906   https://www.wikiart.org/en/vincent-van-gogh/a-...    NaN    NaN    NaN
# 1008  https://www.wikiart.org/en/canaletto/a-regatta...    NaN    NaN    NaN
#
#         tmp
# 794   check
# 822   check
# ...

# %%
print(check_5000.shape)
check_5000.head()
# Out:
# (436, 11)
#       Column        Art_ID          Title            Artist  \
# 5000   86059  Kaggle_69987       Untitled      Paritosh Sen
# 5001   86094  Kaggle_45470       A Shunga      Ike no Taiga
# 5002   86124  Kaggle_56961    Marquisette  Raphael Kirchner
# 5003   86127  Kaggle_40279  Self-Portrait        Cuno Amiet
# 5004   86135  Kaggle_35959      Creatures     Jules Perahim
#
#                                               Wiki_Link  Style  Genre  Media  \
# 5000  ['https://www.wikiart.org/en/paritosh-sen/unti...    NaN    NaN    NaN
# 5001  ['https://www.wikiart.org/en/ike-no-taiga/a-sh...    NaN    NaN    NaN
# 5002  ['https://www.wikiart.org/en/raphael-kirchner/...    NaN    NaN    NaN
# 5003  ['https://www.wikiart.org/en/cuno-amiet/self-p...    NaN    NaN    NaN
# 5004  ['https://www.wikiart.org/en/jules-perahim/cre...    NaN    NaN    NaN
#
#         tmp New_Wiki_Link img_src
# 5000  check           NaN     NaN
# 5001  check           NaN     NaN
# ...

# %%
check_0 = check_0[0:1000]
check_1000 = check_1000[1000:1500]
check_1500 = check_1500[1500:2000]
check_2000 = check_2000[2000:2500]
check_2500 = check_2500[2500:3000]
check_4000 = check_4000[4000:4500]
check_4500 = check_4500[4500:5000]

# %%
check_0 = pd.read_csv(path + './check_kaggle_unique_0.csv')
check_1000 = pd.read_csv(path + './check_kaggle_unique_1000.csv')
check_1500 = pd.read_csv(path + './check_kaggle_unique_1500.csv')
check_2000 = pd.read_csv(path + './check_kaggle_unique_2000.csv')
check_2500 = pd.read_csv(path + './check_kaggle_unique_2500.csv')
check_3000 = pd.read_csv(path + './check_kaggle_unique_3000.csv')
check_3500 = pd.read_csv(path + './check_kaggle_unique_3500.csv')
check_4000 = pd.read_csv(path + './check_kaggle_unique_4000.csv')
check_4500 = pd.read_csv(path + './check_kaggle_unique_4500.csv')
check_5000 = pd.read_csv(path + './check_kaggle_unique_5000.csv')

# %%
check_kaggle_unique = pd.concat([check_0, check_1000])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_1500])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_2000])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_2500])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_3000])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_3500])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_4000])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_4500])
check_kaggle_unique = pd.concat([check_kaggle_unique, check_5000])

# %%
check_kaggle_unique.to_csv('./tmp.csv')

# %%
check_kaggle_unique2 = check_kaggle_unique[~(check_kaggle_unique['New_Wiki_Link'] == '[]')]

# %%
check_kaggle_unique2.to_csv('./tmp.csv')

# %%
check_kaggle_unique2.index = range(len(check_kaggle_unique2))

# %%
check_kaggle_unique2.loc[2, 'New_Wiki_Link']
# Out:
# "['https://www.wikiart.org/en/mark-rothko/untitled-10', 'https://www.wikiart.org/en/mark-rothko/untitled-4', 'https://www.wikiart.org/en/mark-rothko/not_detected_242131', 'https://www.wikiart.org/en/mark-rothko/untitled-1968-2', 'https://www.wikiart.org/en/mark-rothko/untitled-1969', 'https://www.wikiart.org/en/mark-rothko/untitled-1969-1', 'https://www.wikiart.org/en/mark-rothko/untitled-1969-2']"

# %%
test[2]
# Out:
# "['https://www.wikiart.org/en/francois-boucher/rinaldo-and-armida-1734']"

# %%
check_kaggle_unique2
# Out:
#      Column        Art_ID                                  Title  \
# 0         7  Kaggle_49823  Small Bird on a Branch of Kaidozakura
# 1        18  Kaggle_82352         The Garden of Earthly Delights
# 2        20  Kaggle_85864                               Untitled
# 3        37  Kaggle_15715                          Self-portrait
# 4        38  Kaggle_59486                          Self Portrait
# ..      ...           ...                                    ...
# 431  103123  Kaggle_22944                               Untitled
# 432  103137  Kaggle_47270                                   Alpa
# 433  103179  Kaggle_21218                               THE PUTT
# 434  103184  Kaggle_11474                              THE DRIVE
# 435  103219   Kaggle_1351                           THE APPROACH
#
#                    Artist                                          Wiki_Link  \
# 0               Hiroshige  ['https://www.wikiart.org/en/hiroshige/small-b...
# ...

# %%
check_kaggle_unique_tmp = check_kaggle_unique[:5000]

# %%
print(check_kaggle_unique_tmp.loc[250, 'New_Wiki_Link'])
# Out:
# 250    []
# 250    []
# 250    []
# Name: New_Wiki_Link, dtype: object

# %%
check_kaggle_unique_tmp.iloc[10]['New_Wiki_Link']
# Out:
# "['https://www.wikiart.org/en/ferdinand-hodler/the-reaper', 'https://www.wikiart.org/en/ferdinand-hodler/the-reaper-1910']"

# %%
check_kaggle_unique[pd.isnull(check_kaggle_unique['New_Wiki_Link'])]
# Out:
#       Column         Art_ID  \
# 5000   86059   Kaggle_69987
# 5001   86094   Kaggle_45470
# 5002   86124   Kaggle_56961
# 5003   86127   Kaggle_40279
# 5004   86135   Kaggle_35959
# 5005   86153   Kaggle_25929
# 5006   86173   Kaggle_81743
# 5007   86180   Kaggle_62176
# 5008   86214   Kaggle_30900
# 5009   86216     Kaggle_556
# 5010   86226   Kaggle_14353
# 5011   86305   Kaggle_22888
# 5012   86328   Kaggle_62905
# 5013   86340   Kaggle_62829
# 5014   86343   Kaggle_30355
# 5015   86407     Kaggle_615
# 5016   86412   Kaggle_86938
# 5017   86488   Kaggle_94422
# 5018   86489   Kaggle_86950
# 5019   86513   Kaggle_34403
# 5020   86559   Kaggle_84889
# 5021   86586    Kaggle_2093
# 5022   86603   Kaggle_52031
# 5023   86608   Kaggle_16537
# 5024   86611   Kaggle_57089
# 5025   86639   Kaggle_91639
# 5026   86645    Kaggle_3820
# 5027   86647   Kaggle_69779
# 5028   86656   Kaggle_50496
# 5029   86705   Kaggle_95293
# 5030   86708   Kaggle_35633
# 5031   86760   Kaggle_14899
# ...

# %%
check_5000
# Out:
#       Column         Art_ID  \
# 5000   86059   Kaggle_69987
# 5001   86094   Kaggle_45470
# 5002   86124   Kaggle_56961
# 5003   86127   Kaggle_40279
# 5004   86135   Kaggle_35959
# 5005   86153   Kaggle_25929
# 5006   86173   Kaggle_81743
# 5007   86180   Kaggle_62176
# 5008   86214   Kaggle_30900
# 5009   86216     Kaggle_556
# 5010   86226   Kaggle_14353
# 5011   86305   Kaggle_22888
# 5012   86328   Kaggle_62905
# 5013   86340   Kaggle_62829
# 5014   86343   Kaggle_30355
# 5015   86407     Kaggle_615
# 5016   86412   Kaggle_86938
# 5017   86488   Kaggle_94422
# 5018   86489   Kaggle_86950
# 5019   86513   Kaggle_34403
# 5020   86559   Kaggle_84889
# 5021   86586    Kaggle_2093
# 5022   86603   Kaggle_52031
# 5023   86608   Kaggle_16537
# 5024   86611   Kaggle_57089
# 5025   86639   Kaggle_91639
# 5026   86645    Kaggle_3820
# 5027   86647   Kaggle_69779
# 5028   86656   Kaggle_50496
# 5029   86705   Kaggle_95293
# 5030   86708   Kaggle_35633
# 5031   86760   Kaggle_14899
# ...
